# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
sys.path.append('./SALSA-CLRS/')

import torch
from model.GINE import GINE

from loguru import logger
from baselines.core.models.encoder import Encoder
from baselines.core.models.decoder import Decoder
from baselines.core.loss import CLRSLoss
from salsaclrs import specs

device = torch.device('cuda')

Ks = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
circuit_algorithm = 'greedy'
prune = True
seed = 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from EncodeProcessDecode import EncodeProcessDecode
algorithms = ['bfs', 'dfs', 'dijkstra', 'mst_prim', 'bellman_ford', 'articulation_points', 'bridges']
output_types = {
    'bfs' : 'pointer',
    'dfs' : 'pointer',
    'dijkstra' : 'pointer',
    'mst_prim' : 'pointer',
    'bellman_ford' : 'pointer',
    'articulation_points' : 'mask',
    'bridges' : 'edge_mask',
}
accuracy_types = {
    'bfs' : 'node_accuracy',
    'dfs' : 'node_accuracy',
    'dijkstra' : 'node_accuracy',
    'mst_prim' : 'node_accuracy',
    'bellman_ford' : 'node_accuracy',
    'articulation_points' : 'node_accuracy',
    'bridges' : 'edge_accuracy',
}
logger.disable('baselines.core.models.encoder')
logger.disable('baselines.core.models.decoder')

hidden_dim = 128
encoders = torch.nn.ModuleDict({
    task : Encoder(specs=specs.SPECS[task]) for task in algorithms
})

decoders = torch.nn.ModuleDict({
    task : Decoder(specs=specs.SPECS[task], 
                   hidden_dim = hidden_dim * 2,
                   no_hint=False) for task in algorithms
})

for encoder in encoders.values():
    encoder.to(device)
for decoder in decoders.values():
    decoder.to(device)
processor = GINE(3*128, 128, 2, 128, edge_dim=1, aggr='max')
processor.to(device)
model = EncodeProcessDecode(encoders, decoders, processor, device=device)

model_checkpoint = f'model_in_progress_199_seed_{seed}'
model_state = torch.load(f'checkpoints/{model_checkpoint}.pt', map_location=device)
model.load_state_dict(model_state)
model.eval()
model.to(device)
# Out:
# EncodeProcessDecode(
#   (encoders): ModuleDict(
#     (bfs): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#         (s): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (dfs): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (dijkstra): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#         (s): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (mst_prim): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#         (s): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (bellman_ford): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#         (s): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (articulation_points): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#     (bridges): Encoder(
#       (encoder): ModuleDict(
#         (pos): NodeBaseEncoder(
#           (lin): Linear(in_features=1, out_features=128, bias=True)
#         )
#       )
#     )
#   )
#   (decoders): ModuleDict(
#     (bfs): Decoder(
#       (decoder): ModuleDict(
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (reach): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (dfs): Decoder(
#       (decoder): ModuleDict(
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (color): NodeCategoricalDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (d): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (f): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_prev): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (s): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (u): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (v): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_last): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (time): GraphBaseDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (dijkstra): Decoder(
#       (decoder): ModuleDict(
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (d): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (mark): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (in_queue): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (u): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (mst_prim): Decoder(
#       (decoder): ModuleDict(
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (key): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (mark): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (in_queue): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (u): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (bellman_ford): Decoder(
#       (decoder): ModuleDict(
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (d): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (msk): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (articulation_points): Decoder(
#       (decoder): ModuleDict(
#         (is_cut): NodeMaskDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (color): NodeCategoricalDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (d): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (f): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (low): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (child_cnt): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_prev): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (s): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (u): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (v): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_last): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (time): GraphBaseDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#     (bridges): Decoder(
#       (decoder): ModuleDict(
#         (is_bridge): EdgeMaskDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (pi): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (color): NodeCategoricalDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (d): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (f): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (low): NodeScalarDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_prev): NodePointerDecoder(
#           (source_lin): Linear(in_features=256, out_features=256, bias=True)
#           (target_lin): Linear(in_features=256, out_features=256, bias=True)
#         )
#         (s): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (u): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (v): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (s_last): NodeMaskOneDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#         (time): GraphBaseDecoder(
#           (lin): Linear(in_features=256, out_features=1, bias=True)
#         )
#       )
#     )
#   )
#   (processor): GINE(384, 128, num_layers=2)
# )

# %%
clean_directory = './data_clean/'
corrupted_directory = './data_corrupted/'

num_samples = 128
clean_data = {algorithm : [torch.load(f'{clean_directory}/{algorithm}/data_{i}.pt', weights_only=False) for i in range(num_samples)] for algorithm in algorithms}
corrupted_data = {algorithm : [torch.load(f'{corrupted_directory}/{algorithm}/data_{i}.pt', weights_only=False) for i in range(num_samples)] for algorithm in algorithms}
criteria = {algorithm : CLRSLoss(specs=specs.SPECS[algorithm], hidden_loss_type='l2') for algorithm in algorithms}

# %%
import os
from SALSACLRSComputationGraph import SALSACLRSComputationGraph
import networkx as nx
compute_scores = ['weight_grad', 'EAP', 'EAP-IG']

G = SALSACLRSComputationGraph(model, special_modules=['convs.0.lin', 'convs.1.lin'])
G.add_module('convs.0.lin', processor.convs[0].lin,
            module_inputs='edge_attr',
            module_outputs=0,
            layer=0)
G.add_module('convs.1.lin', processor.convs[1].lin,
            module_inputs='edge_attr',
            module_outputs=2,
            layer=0)
G.correct_layers()
print(G.number_of_edges())

G_save_string = f'G_scores_new_{model_checkpoint}.pt'
if os.path.exists(f'scored_computation_graphs/{G_save_string}'):
    G_scores = torch.load(f'scored_computation_graphs/{G_save_string}', weights_only=False)
    for edge, data in G_scores.items():
        G.add_edge(*edge, **data)
    print(f'Loaded existing scored computation graph from scored_computation_graphs/{G_save_string}')
else:
    print('Creating new computation graph...')
    for algorithm in algorithms:
        for score_method in compute_scores:
            if score_method == 'EAP-IG':
                print(f'Calculating {score_method} scores for {algorithm}...')
                G.calculate_scores(algorithm, clean_data[algorithm], corrupted_data[algorithm], criteria[algorithm], which=score_method, **{'steps': 20})
            else:
                print(f'Calculating {score_method} scores for {algorithm}...')
                G.calculate_scores(algorithm, clean_data[algorithm], corrupted_data[algorithm], criteria[algorithm], which=score_method)

    # Only save the scores since saving the whole objects pickles the model
    G_scores = {(u,v) : data for u, v, data in G.edges(data=True)}
    torch.save(G_scores, f'scored_computation_graphs/{G_save_string}')
# Out:
# 99712
# Loaded existing scored computation graph from scored_computation_graphs/G_scores_new_model_in_progress_199_seed_2.pt

# %%
from SALSACLRSComputationGraph import SALSACLRSCircuit

score_methods = ['weight', 'weight_grad', 'EAP', 'EAP-IG']
circuit_path = f'salsa_clrs_circuits_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt'
if os.path.exists(f'circuits/{circuit_path}'):
    circuits = torch.load(f'circuits/{circuit_path}', weights_only=False)
else:
    circuits = {}
for K in Ks:
    skipped = False
    if circuits.get(('bridges', K, 'weight')) is None:
        weight_circuit = SALSACLRSCircuit(model, G, K, key='weight', circuit_algorithm=circuit_algorithm, prune=prune)
    for algorithm in algorithms:
        for score_method in score_methods:
            if (algorithm, K, score_method) in circuits:
                print(f'Circuit for {algorithm} with K={K} and score method {score_method} already exists. Skipping...')
                skipped = True
            elif score_method == 'weight':
                circuits[(algorithm, K, score_method)] = weight_circuit
                print(f'{algorithm} circuit with K={K} and score method {score_method}: {circuits[(algorithm, K, score_method)].number_of_edges()} edges')
            else:
                circuits[(algorithm, K, score_method)] = SALSACLRSCircuit(model, G, K, key=f'{score_method}_{algorithm}', circuit_algorithm=circuit_algorithm, prune=prune)
                print(f'{algorithm} circuit with K={K} and score method {score_method}: {circuits[(algorithm, K, score_method)].number_of_edges()} edges')
    for circuit in circuits.values():
        circuit.G = None
        circuit.model = None
        circuit.EncodeProcessDecode = None
    if not skipped:
        torch.save(circuits, f'circuits/{circuit_path}')
for circuit in circuits.values():
    circuit.G = G
    circuit.EncodeProcessDecode = model
    circuit.model = processor
# Out:
# Circuit for bfs with K=1000 and score method weight already exists. Skipping...
# Circuit for bfs with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=1000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=1000 and score method weight already exists. Skipping...
# Circuit for dfs with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=1000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=1000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=1000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=1000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=1000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=1000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=1000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=1000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=1000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=1000 and score method weight already exists. Skipping...
# Circuit for bridges with K=1000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=1000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=1000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=2000 and score method weight already exists. Skipping...
# Circuit for bfs with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=2000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=2000 and score method weight already exists. Skipping...
# Circuit for dfs with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=2000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=2000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=2000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=2000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=2000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=2000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=2000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=2000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=2000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=2000 and score method weight already exists. Skipping...
# Circuit for bridges with K=2000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=2000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=2000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=3000 and score method weight already exists. Skipping...
# Circuit for bfs with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=3000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=3000 and score method weight already exists. Skipping...
# Circuit for dfs with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=3000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=3000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=3000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=3000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=3000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=3000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=3000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=3000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=3000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=3000 and score method weight already exists. Skipping...
# Circuit for bridges with K=3000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=3000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=3000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=4000 and score method weight already exists. Skipping...
# Circuit for bfs with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=4000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=4000 and score method weight already exists. Skipping...
# Circuit for dfs with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=4000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=4000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=4000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=4000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=4000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=4000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=4000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=4000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=4000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=4000 and score method weight already exists. Skipping...
# Circuit for bridges with K=4000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=4000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=4000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=5000 and score method weight already exists. Skipping...
# Circuit for bfs with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=5000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=5000 and score method weight already exists. Skipping...
# Circuit for dfs with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=5000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=5000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=5000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=5000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=5000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=5000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=5000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=5000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=5000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=5000 and score method weight already exists. Skipping...
# Circuit for bridges with K=5000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=5000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=5000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=6000 and score method weight already exists. Skipping...
# Circuit for bfs with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=6000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=6000 and score method weight already exists. Skipping...
# Circuit for dfs with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=6000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=6000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=6000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=6000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=6000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=6000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=6000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=6000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=6000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=6000 and score method weight already exists. Skipping...
# Circuit for bridges with K=6000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=6000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=6000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=7000 and score method weight already exists. Skipping...
# Circuit for bfs with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=7000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=7000 and score method weight already exists. Skipping...
# Circuit for dfs with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=7000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=7000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=7000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=7000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=7000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=7000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=7000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=7000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=7000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=7000 and score method weight already exists. Skipping...
# Circuit for bridges with K=7000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=7000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=7000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=8000 and score method weight already exists. Skipping...
# Circuit for bfs with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=8000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=8000 and score method weight already exists. Skipping...
# Circuit for dfs with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=8000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=8000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=8000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=8000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=8000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=8000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=8000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=8000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=8000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=8000 and score method weight already exists. Skipping...
# Circuit for bridges with K=8000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=8000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=8000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=9000 and score method weight already exists. Skipping...
# Circuit for bfs with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=9000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=9000 and score method weight already exists. Skipping...
# Circuit for dfs with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=9000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=9000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=9000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=9000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=9000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=9000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=9000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=9000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=9000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=9000 and score method weight already exists. Skipping...
# Circuit for bridges with K=9000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=9000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=9000 and score method EAP-IG already exists. Skipping...
# Circuit for bfs with K=10000 and score method weight already exists. Skipping...
# Circuit for bfs with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for bfs with K=10000 and score method EAP already exists. Skipping...
# Circuit for bfs with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for dfs with K=10000 and score method weight already exists. Skipping...
# Circuit for dfs with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for dfs with K=10000 and score method EAP already exists. Skipping...
# Circuit for dfs with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for dijkstra with K=10000 and score method weight already exists. Skipping...
# Circuit for dijkstra with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for dijkstra with K=10000 and score method EAP already exists. Skipping...
# Circuit for dijkstra with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for mst_prim with K=10000 and score method weight already exists. Skipping...
# Circuit for mst_prim with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for mst_prim with K=10000 and score method EAP already exists. Skipping...
# Circuit for mst_prim with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for bellman_ford with K=10000 and score method weight already exists. Skipping...
# Circuit for bellman_ford with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for bellman_ford with K=10000 and score method EAP already exists. Skipping...
# Circuit for bellman_ford with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for articulation_points with K=10000 and score method weight already exists. Skipping...
# Circuit for articulation_points with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for articulation_points with K=10000 and score method EAP already exists. Skipping...
# Circuit for articulation_points with K=10000 and score method EAP-IG already exists. Skipping...
# Circuit for bridges with K=10000 and score method weight already exists. Skipping...
# Circuit for bridges with K=10000 and score method weight_grad already exists. Skipping...
# Circuit for bridges with K=10000 and score method EAP already exists. Skipping...
# Circuit for bridges with K=10000 and score method EAP-IG already exists. Skipping...

# %%
import itertools
jaccard_indices = {}
weighted_jaccard_indices = {}
intersections = {}
for alg1, alg2 in itertools.product(algorithms, repeat=2):
    for score_method in compute_scores:
        for K in Ks:
            circuit1_edges = set(circuits[(alg1, K, score_method)].edges)
            circuit2_edges = set(circuits[(alg2, K, score_method)].edges)
            intersection = circuit1_edges & circuit2_edges
            union = circuit1_edges | circuit2_edges
            intersections[(alg1, alg2, K)] = intersection
            union_score = sum([abs(G.edges[edge].get('weight')) for edge in union])
            intersection_score = sum([abs(G.edges[edge].get('weight')) for edge in intersection])
            weighted_jaccard_index = float(intersection_score / union_score if union_score > 0 else 0)
            jaccard_index = float(len(intersection) / len(union) if len(union) > 0 else 0)
            jaccard_indices[(alg1, alg2, K, score_method)] = jaccard_index
            weighted_jaccard_indices[(alg1, alg2, K, score_method)] = weighted_jaccard_index
            if alg1 != alg2:
                print(f"{alg1} ∩ {alg2} at K={K}: {len(intersection)} edges, Jaccard Index: {jaccard_index:.4f}, Weighted Jaccard Index: {weighted_jaccard_index:.4f}")
# Out:
# bfs ∩ dfs at K=1000: 49 edges, Jaccard Index: 0.0369, Weighted Jaccard Index: 0.0377
# bfs ∩ dfs at K=2000: 194 edges, Jaccard Index: 0.0667, Weighted Jaccard Index: 0.0730
# bfs ∩ dfs at K=3000: 419 edges, Jaccard Index: 0.0909, Weighted Jaccard Index: 0.1018
# bfs ∩ dfs at K=4000: 680 edges, Jaccard Index: 0.1086, Weighted Jaccard Index: 0.1192
# bfs ∩ dfs at K=5000: 1019 edges, Jaccard Index: 0.1300, Weighted Jaccard Index: 0.1480
# bfs ∩ dfs at K=6000: 1293 edges, Jaccard Index: 0.1365, Weighted Jaccard Index: 0.1572
# bfs ∩ dfs at K=7000: 1642 edges, Jaccard Index: 0.1473, Weighted Jaccard Index: 0.1676
# bfs ∩ dfs at K=8000: 2039 edges, Jaccard Index: 0.1590, Weighted Jaccard Index: 0.1819
# bfs ∩ dfs at K=9000: 2401 edges, Jaccard Index: 0.1668, Weighted Jaccard Index: 0.1918
# bfs ∩ dfs at K=10000: 2862 edges, Jaccard Index: 0.1795, Weighted Jaccard Index: 0.2060
# bfs ∩ dfs at K=1000: 22 edges, Jaccard Index: 0.0217, Weighted Jaccard Index: 0.0404
# bfs ∩ dfs at K=2000: 76 edges, Jaccard Index: 0.0345, Weighted Jaccard Index: 0.0516
# bfs ∩ dfs at K=3000: 161 edges, Jaccard Index: 0.0472, Weighted Jaccard Index: 0.0578
# bfs ∩ dfs at K=4000: 310 edges, Jaccard Index: 0.0640, Weighted Jaccard Index: 0.0873
# bfs ∩ dfs at K=5000: 424 edges, Jaccard Index: 0.0666, Weighted Jaccard Index: 0.0879
# bfs ∩ dfs at K=6000: 728 edges, Jaccard Index: 0.0950, Weighted Jaccard Index: 0.1092
# bfs ∩ dfs at K=7000: 1000 edges, Jaccard Index: 0.1111, Weighted Jaccard Index: 0.1247
# bfs ∩ dfs at K=8000: 1295 edges, Jaccard Index: 0.1267, Weighted Jaccard Index: 0.1414
# bfs ∩ dfs at K=9000: 1559 edges, Jaccard Index: 0.1358, Weighted Jaccard Index: 0.1504
# bfs ∩ dfs at K=10000: 1847 edges, Jaccard Index: 0.1456, Weighted Jaccard Index: 0.1638
# bfs ∩ dfs at K=1000: 21 edges, Jaccard Index: 0.0178, Weighted Jaccard Index: 0.0264
# bfs ∩ dfs at K=2000: 88 edges, Jaccard Index: 0.0351, Weighted Jaccard Index: 0.0445
# bfs ∩ dfs at K=3000: 175 edges, Jaccard Index: 0.0460, Weighted Jaccard Index: 0.0525
# bfs ∩ dfs at K=4000: 283 edges, Jaccard Index: 0.0550, Weighted Jaccard Index: 0.0669
# bfs ∩ dfs at K=5000: 450 edges, Jaccard Index: 0.0703, Weighted Jaccard Index: 0.0844
# bfs ∩ dfs at K=6000: 599 edges, Jaccard Index: 0.0767, Weighted Jaccard Index: 0.0919
# bfs ∩ dfs at K=7000: 826 edges, Jaccard Index: 0.0901, Weighted Jaccard Index: 0.1064
# bfs ∩ dfs at K=8000: 1143 edges, Jaccard Index: 0.1095, Weighted Jaccard Index: 0.1266
# bfs ∩ dfs at K=9000: 1466 edges, Jaccard Index: 0.1255, Weighted Jaccard Index: 0.1458
# bfs ∩ dfs at K=10000: 1745 edges, Jaccard Index: 0.1351, Weighted Jaccard Index: 0.1553
# bfs ∩ dijkstra at K=1000: 49 edges, Jaccard Index: 0.0395, Weighted Jaccard Index: 0.0411
# bfs ∩ dijkstra at K=2000: 124 edges, Jaccard Index: 0.0431, Weighted Jaccard Index: 0.0494
# bfs ∩ dijkstra at K=3000: 289 edges, Jaccard Index: 0.0637, Weighted Jaccard Index: 0.0706
# bfs ∩ dijkstra at K=4000: 486 edges, Jaccard Index: 0.0789, Weighted Jaccard Index: 0.0861
# bfs ∩ dijkstra at K=5000: 717 edges, Jaccard Index: 0.0919, Weighted Jaccard Index: 0.1010
# bfs ∩ dijkstra at K=6000: 976 edges, Jaccard Index: 0.1025, Weighted Jaccard Index: 0.1136
# bfs ∩ dijkstra at K=7000: 1286 edges, Jaccard Index: 0.1154, Weighted Jaccard Index: 0.1290
# bfs ∩ dijkstra at K=8000: 1618 edges, Jaccard Index: 0.1254, Weighted Jaccard Index: 0.1407
# bfs ∩ dijkstra at K=9000: 2015 edges, Jaccard Index: 0.1384, Weighted Jaccard Index: 0.1536
# bfs ∩ dijkstra at K=10000: 2471 edges, Jaccard Index: 0.1528, Weighted Jaccard Index: 0.1664
# bfs ∩ dijkstra at K=1000: 3 edges, Jaccard Index: 0.0031, Weighted Jaccard Index: 0.0053
# bfs ∩ dijkstra at K=2000: 34 edges, Jaccard Index: 0.0153, Weighted Jaccard Index: 0.0176
# bfs ∩ dijkstra at K=3000: 88 edges, Jaccard Index: 0.0252, Weighted Jaccard Index: 0.0302
# bfs ∩ dijkstra at K=4000: 220 edges, Jaccard Index: 0.0437, Weighted Jaccard Index: 0.0540
# bfs ∩ dijkstra at K=5000: 348 edges, Jaccard Index: 0.0543, Weighted Jaccard Index: 0.0671
# bfs ∩ dijkstra at K=6000: 466 edges, Jaccard Index: 0.0589, Weighted Jaccard Index: 0.0742
# bfs ∩ dijkstra at K=7000: 633 edges, Jaccard Index: 0.0678, Weighted Jaccard Index: 0.0873
# bfs ∩ dijkstra at K=8000: 814 edges, Jaccard Index: 0.0769, Weighted Jaccard Index: 0.1004
# bfs ∩ dijkstra at K=9000: 1097 edges, Jaccard Index: 0.0919, Weighted Jaccard Index: 0.1174
# bfs ∩ dijkstra at K=10000: 1354 edges, Jaccard Index: 0.1017, Weighted Jaccard Index: 0.1292
# bfs ∩ dijkstra at K=1000: 3 edges, Jaccard Index: 0.0032, Weighted Jaccard Index: 0.0021
# bfs ∩ dijkstra at K=2000: 30 edges, Jaccard Index: 0.0152, Weighted Jaccard Index: 0.0216
# bfs ∩ dijkstra at K=3000: 104 edges, Jaccard Index: 0.0332, Weighted Jaccard Index: 0.0439
# bfs ∩ dijkstra at K=4000: 174 edges, Jaccard Index: 0.0401, Weighted Jaccard Index: 0.0529
# bfs ∩ dijkstra at K=5000: 295 edges, Jaccard Index: 0.0475, Weighted Jaccard Index: 0.0602
# bfs ∩ dijkstra at K=6000: 431 edges, Jaccard Index: 0.0575, Weighted Jaccard Index: 0.0724
# bfs ∩ dijkstra at K=7000: 623 edges, Jaccard Index: 0.0705, Weighted Jaccard Index: 0.0903
# bfs ∩ dijkstra at K=8000: 809 edges, Jaccard Index: 0.0793, Weighted Jaccard Index: 0.1032
# bfs ∩ dijkstra at K=9000: 1049 edges, Jaccard Index: 0.0909, Weighted Jaccard Index: 0.1152
# bfs ∩ dijkstra at K=10000: 1255 edges, Jaccard Index: 0.0975, Weighted Jaccard Index: 0.1218
# bfs ∩ mst_prim at K=1000: 30 edges, Jaccard Index: 0.0208, Weighted Jaccard Index: 0.0224
# bfs ∩ mst_prim at K=2000: 154 edges, Jaccard Index: 0.0491, Weighted Jaccard Index: 0.0549
# bfs ∩ mst_prim at K=3000: 363 edges, Jaccard Index: 0.0766, Weighted Jaccard Index: 0.0889
# bfs ∩ mst_prim at K=4000: 522 edges, Jaccard Index: 0.0816, Weighted Jaccard Index: 0.0921
# bfs ∩ mst_prim at K=5000: 736 edges, Jaccard Index: 0.0911, Weighted Jaccard Index: 0.1005
# bfs ∩ mst_prim at K=6000: 967 edges, Jaccard Index: 0.0990, Weighted Jaccard Index: 0.1084
# bfs ∩ mst_prim at K=7000: 1261 edges, Jaccard Index: 0.1101, Weighted Jaccard Index: 0.1206
# bfs ∩ mst_prim at K=8000: 1619 edges, Jaccard Index: 0.1229, Weighted Jaccard Index: 0.1360
# bfs ∩ mst_prim at K=9000: 1980 edges, Jaccard Index: 0.1345, Weighted Jaccard Index: 0.1495
# bfs ∩ mst_prim at K=10000: 2369 edges, Jaccard Index: 0.1455, Weighted Jaccard Index: 0.1594
# bfs ∩ mst_prim at K=1000: 20 edges, Jaccard Index: 0.0191, Weighted Jaccard Index: 0.0323
# bfs ∩ mst_prim at K=2000: 65 edges, Jaccard Index: 0.0279, Weighted Jaccard Index: 0.0444
# bfs ∩ mst_prim at K=3000: 170 edges, Jaccard Index: 0.0476, Weighted Jaccard Index: 0.0636
# bfs ∩ mst_prim at K=4000: 281 edges, Jaccard Index: 0.0576, Weighted Jaccard Index: 0.0769
# bfs ∩ mst_prim at K=5000: 402 edges, Jaccard Index: 0.0637, Weighted Jaccard Index: 0.0810
# bfs ∩ mst_prim at K=6000: 584 edges, Jaccard Index: 0.0752, Weighted Jaccard Index: 0.0947
# bfs ∩ mst_prim at K=7000: 763 edges, Jaccard Index: 0.0837, Weighted Jaccard Index: 0.1050
# bfs ∩ mst_prim at K=8000: 945 edges, Jaccard Index: 0.0913, Weighted Jaccard Index: 0.1132
# bfs ∩ mst_prim at K=9000: 1163 edges, Jaccard Index: 0.1001, Weighted Jaccard Index: 0.1216
# bfs ∩ mst_prim at K=10000: 1407 edges, Jaccard Index: 0.1098, Weighted Jaccard Index: 0.1323
# bfs ∩ mst_prim at K=1000: 32 edges, Jaccard Index: 0.0342, Weighted Jaccard Index: 0.0563
# bfs ∩ mst_prim at K=2000: 82 edges, Jaccard Index: 0.0385, Weighted Jaccard Index: 0.0562
# bfs ∩ mst_prim at K=3000: 157 edges, Jaccard Index: 0.0475, Weighted Jaccard Index: 0.0667
# bfs ∩ mst_prim at K=4000: 268 edges, Jaccard Index: 0.0588, Weighted Jaccard Index: 0.0755
# bfs ∩ mst_prim at K=5000: 425 edges, Jaccard Index: 0.0737, Weighted Jaccard Index: 0.0972
# bfs ∩ mst_prim at K=6000: 561 edges, Jaccard Index: 0.0772, Weighted Jaccard Index: 0.1020
# bfs ∩ mst_prim at K=7000: 741 edges, Jaccard Index: 0.0867, Weighted Jaccard Index: 0.1120
# bfs ∩ mst_prim at K=8000: 922 edges, Jaccard Index: 0.0924, Weighted Jaccard Index: 0.1184
# bfs ∩ mst_prim at K=9000: 1170 edges, Jaccard Index: 0.1040, Weighted Jaccard Index: 0.1314
# bfs ∩ mst_prim at K=10000: 1449 edges, Jaccard Index: 0.1160, Weighted Jaccard Index: 0.1459
# bfs ∩ bellman_ford at K=1000: 15 edges, Jaccard Index: 0.0110, Weighted Jaccard Index: 0.0122
# bfs ∩ bellman_ford at K=2000: 96 edges, Jaccard Index: 0.0319, Weighted Jaccard Index: 0.0383
# bfs ∩ bellman_ford at K=3000: 217 edges, Jaccard Index: 0.0456, Weighted Jaccard Index: 0.0521
# bfs ∩ bellman_ford at K=4000: 408 edges, Jaccard Index: 0.0636, Weighted Jaccard Index: 0.0747
# bfs ∩ bellman_ford at K=5000: 651 edges, Jaccard Index: 0.0807, Weighted Jaccard Index: 0.0907
# bfs ∩ bellman_ford at K=6000: 922 edges, Jaccard Index: 0.0944, Weighted Jaccard Index: 0.1091
# bfs ∩ bellman_ford at K=7000: 1221 edges, Jaccard Index: 0.1059, Weighted Jaccard Index: 0.1211
# bfs ∩ bellman_ford at K=8000: 1608 edges, Jaccard Index: 0.1211, Weighted Jaccard Index: 0.1363
# bfs ∩ bellman_ford at K=9000: 1951 edges, Jaccard Index: 0.1309, Weighted Jaccard Index: 0.1488
# bfs ∩ bellman_ford at K=10000: 2382 edges, Jaccard Index: 0.1443, Weighted Jaccard Index: 0.1641
# bfs ∩ bellman_ford at K=1000: 3 edges, Jaccard Index: 0.0034, Weighted Jaccard Index: 0.0069
# bfs ∩ bellman_ford at K=2000: 27 edges, Jaccard Index: 0.0125, Weighted Jaccard Index: 0.0173
# bfs ∩ bellman_ford at K=3000: 71 edges, Jaccard Index: 0.0205, Weighted Jaccard Index: 0.0274
# bfs ∩ bellman_ford at K=4000: 217 edges, Jaccard Index: 0.0439, Weighted Jaccard Index: 0.0511
# bfs ∩ bellman_ford at K=5000: 323 edges, Jaccard Index: 0.0503, Weighted Jaccard Index: 0.0578
# bfs ∩ bellman_ford at K=6000: 454 edges, Jaccard Index: 0.0579, Weighted Jaccard Index: 0.0657
# bfs ∩ bellman_ford at K=7000: 608 edges, Jaccard Index: 0.0642, Weighted Jaccard Index: 0.0742
# bfs ∩ bellman_ford at K=8000: 791 edges, Jaccard Index: 0.0733, Weighted Jaccard Index: 0.0850
# bfs ∩ bellman_ford at K=9000: 991 edges, Jaccard Index: 0.0820, Weighted Jaccard Index: 0.0974
# bfs ∩ bellman_ford at K=10000: 1273 edges, Jaccard Index: 0.0948, Weighted Jaccard Index: 0.1135
# bfs ∩ bellman_ford at K=1000: 1 edges, Jaccard Index: 0.0012, Weighted Jaccard Index: 0.0025
# bfs ∩ bellman_ford at K=2000: 19 edges, Jaccard Index: 0.0098, Weighted Jaccard Index: 0.0136
# bfs ∩ bellman_ford at K=3000: 62 edges, Jaccard Index: 0.0189, Weighted Jaccard Index: 0.0274
# bfs ∩ bellman_ford at K=4000: 155 edges, Jaccard Index: 0.0331, Weighted Jaccard Index: 0.0455
# bfs ∩ bellman_ford at K=5000: 287 edges, Jaccard Index: 0.0471, Weighted Jaccard Index: 0.0612
# bfs ∩ bellman_ford at K=6000: 427 edges, Jaccard Index: 0.0569, Weighted Jaccard Index: 0.0748
# bfs ∩ bellman_ford at K=7000: 560 edges, Jaccard Index: 0.0621, Weighted Jaccard Index: 0.0833
# bfs ∩ bellman_ford at K=8000: 778 edges, Jaccard Index: 0.0745, Weighted Jaccard Index: 0.0987
# bfs ∩ bellman_ford at K=9000: 956 edges, Jaccard Index: 0.0811, Weighted Jaccard Index: 0.1053
# bfs ∩ bellman_ford at K=10000: 1178 edges, Jaccard Index: 0.0901, Weighted Jaccard Index: 0.1165
# bfs ∩ articulation_points at K=1000: 40 edges, Jaccard Index: 0.0263, Weighted Jaccard Index: 0.0438
# bfs ∩ articulation_points at K=2000: 137 edges, Jaccard Index: 0.0435, Weighted Jaccard Index: 0.0576
# bfs ∩ articulation_points at K=3000: 358 edges, Jaccard Index: 0.0746, Weighted Jaccard Index: 0.0833
# bfs ∩ articulation_points at K=4000: 623 edges, Jaccard Index: 0.0969, Weighted Jaccard Index: 0.1123
# bfs ∩ articulation_points at K=5000: 853 edges, Jaccard Index: 0.1064, Weighted Jaccard Index: 0.1236
# bfs ∩ articulation_points at K=6000: 1152 edges, Jaccard Index: 0.1190, Weighted Jaccard Index: 0.1343
# bfs ∩ articulation_points at K=7000: 1531 edges, Jaccard Index: 0.1358, Weighted Jaccard Index: 0.1500
# bfs ∩ articulation_points at K=8000: 1923 edges, Jaccard Index: 0.1490, Weighted Jaccard Index: 0.1647
# bfs ∩ articulation_points at K=9000: 2278 edges, Jaccard Index: 0.1583, Weighted Jaccard Index: 0.1749
# bfs ∩ articulation_points at K=10000: 2724 edges, Jaccard Index: 0.1714, Weighted Jaccard Index: 0.1898
# bfs ∩ articulation_points at K=1000: 44 edges, Jaccard Index: 0.0350, Weighted Jaccard Index: 0.0613
# bfs ∩ articulation_points at K=2000: 99 edges, Jaccard Index: 0.0371, Weighted Jaccard Index: 0.0554
# bfs ∩ articulation_points at K=3000: 259 edges, Jaccard Index: 0.0652, Weighted Jaccard Index: 0.0908
# bfs ∩ articulation_points at K=4000: 403 edges, Jaccard Index: 0.0758, Weighted Jaccard Index: 0.1007
# bfs ∩ articulation_points at K=5000: 571 edges, Jaccard Index: 0.0845, Weighted Jaccard Index: 0.1109
# bfs ∩ articulation_points at K=6000: 787 edges, Jaccard Index: 0.0967, Weighted Jaccard Index: 0.1258
# bfs ∩ articulation_points at K=7000: 1028 edges, Jaccard Index: 0.1077, Weighted Jaccard Index: 0.1409
# bfs ∩ articulation_points at K=8000: 1292 edges, Jaccard Index: 0.1197, Weighted Jaccard Index: 0.1540
# bfs ∩ articulation_points at K=9000: 1606 edges, Jaccard Index: 0.1342, Weighted Jaccard Index: 0.1710
# bfs ∩ articulation_points at K=10000: 1910 edges, Jaccard Index: 0.1448, Weighted Jaccard Index: 0.1815
# bfs ∩ articulation_points at K=1000: 15 edges, Jaccard Index: 0.0133, Weighted Jaccard Index: 0.0231
# bfs ∩ articulation_points at K=2000: 87 edges, Jaccard Index: 0.0381, Weighted Jaccard Index: 0.0551
# bfs ∩ articulation_points at K=3000: 187 edges, Jaccard Index: 0.0530, Weighted Jaccard Index: 0.0651
# bfs ∩ articulation_points at K=4000: 313 edges, Jaccard Index: 0.0658, Weighted Jaccard Index: 0.0758
# bfs ∩ articulation_points at K=5000: 536 edges, Jaccard Index: 0.0905, Weighted Jaccard Index: 0.1134
# bfs ∩ articulation_points at K=6000: 868 edges, Jaccard Index: 0.1201, Weighted Jaccard Index: 0.1505
# bfs ∩ articulation_points at K=7000: 1170 edges, Jaccard Index: 0.1363, Weighted Jaccard Index: 0.1661
# bfs ∩ articulation_points at K=8000: 1487 edges, Jaccard Index: 0.1510, Weighted Jaccard Index: 0.1838
# bfs ∩ articulation_points at K=9000: 1811 edges, Jaccard Index: 0.1634, Weighted Jaccard Index: 0.2020
# bfs ∩ articulation_points at K=10000: 2119 edges, Jaccard Index: 0.1711, Weighted Jaccard Index: 0.2100
# bfs ∩ bridges at K=1000: 27 edges, Jaccard Index: 0.0206, Weighted Jaccard Index: 0.0230
# bfs ∩ bridges at K=2000: 88 edges, Jaccard Index: 0.0304, Weighted Jaccard Index: 0.0413
# bfs ∩ bridges at K=3000: 188 edges, Jaccard Index: 0.0413, Weighted Jaccard Index: 0.0540
# bfs ∩ bridges at K=4000: 293 edges, Jaccard Index: 0.0466, Weighted Jaccard Index: 0.0619
# bfs ∩ bridges at K=5000: 552 edges, Jaccard Index: 0.0696, Weighted Jaccard Index: 0.0857
# bfs ∩ bridges at K=6000: 746 edges, Jaccard Index: 0.0775, Weighted Jaccard Index: 0.0952
# bfs ∩ bridges at K=7000: 1044 edges, Jaccard Index: 0.0917, Weighted Jaccard Index: 0.1113
# bfs ∩ bridges at K=8000: 1405 edges, Jaccard Index: 0.1070, Weighted Jaccard Index: 0.1289
# bfs ∩ bridges at K=9000: 1724 edges, Jaccard Index: 0.1175, Weighted Jaccard Index: 0.1391
# bfs ∩ bridges at K=10000: 2130 edges, Jaccard Index: 0.1305, Weighted Jaccard Index: 0.1537
# bfs ∩ bridges at K=1000: 34 edges, Jaccard Index: 0.0292, Weighted Jaccard Index: 0.0376
# bfs ∩ bridges at K=2000: 101 edges, Jaccard Index: 0.0407, Weighted Jaccard Index: 0.0581
# bfs ∩ bridges at K=3000: 192 edges, Jaccard Index: 0.0515, Weighted Jaccard Index: 0.0644
# bfs ∩ bridges at K=4000: 353 edges, Jaccard Index: 0.0690, Weighted Jaccard Index: 0.0796
# bfs ∩ bridges at K=5000: 533 edges, Jaccard Index: 0.0805, Weighted Jaccard Index: 0.0909
# bfs ∩ bridges at K=6000: 697 edges, Jaccard Index: 0.0870, Weighted Jaccard Index: 0.0983
# bfs ∩ bridges at K=7000: 875 edges, Jaccard Index: 0.0929, Weighted Jaccard Index: 0.1082
# bfs ∩ bridges at K=8000: 1123 edges, Jaccard Index: 0.1053, Weighted Jaccard Index: 0.1268
# bfs ∩ bridges at K=9000: 1310 edges, Jaccard Index: 0.1085, Weighted Jaccard Index: 0.1344
# bfs ∩ bridges at K=10000: 1575 edges, Jaccard Index: 0.1188, Weighted Jaccard Index: 0.1449
# bfs ∩ bridges at K=1000: 16 edges, Jaccard Index: 0.0256, Weighted Jaccard Index: 0.0221
# bfs ∩ bridges at K=2000: 55 edges, Jaccard Index: 0.0265, Weighted Jaccard Index: 0.0284
# bfs ∩ bridges at K=3000: 121 edges, Jaccard Index: 0.0375, Weighted Jaccard Index: 0.0392
# bfs ∩ bridges at K=4000: 219 edges, Jaccard Index: 0.0490, Weighted Jaccard Index: 0.0553
# bfs ∩ bridges at K=5000: 452 edges, Jaccard Index: 0.0788, Weighted Jaccard Index: 0.0877
# bfs ∩ bridges at K=6000: 668 edges, Jaccard Index: 0.0949, Weighted Jaccard Index: 0.0975
# bfs ∩ bridges at K=7000: 865 edges, Jaccard Index: 0.1035, Weighted Jaccard Index: 0.1080
# bfs ∩ bridges at K=8000: 1057 edges, Jaccard Index: 0.1082, Weighted Jaccard Index: 0.1218
# bfs ∩ bridges at K=9000: 1315 edges, Jaccard Index: 0.1183, Weighted Jaccard Index: 0.1363
# bfs ∩ bridges at K=10000: 1585 edges, Jaccard Index: 0.1287, Weighted Jaccard Index: 0.1501
# dfs ∩ bfs at K=1000: 49 edges, Jaccard Index: 0.0369, Weighted Jaccard Index: 0.0377
# dfs ∩ bfs at K=2000: 194 edges, Jaccard Index: 0.0667, Weighted Jaccard Index: 0.0730
# dfs ∩ bfs at K=3000: 419 edges, Jaccard Index: 0.0909, Weighted Jaccard Index: 0.1018
# dfs ∩ bfs at K=4000: 680 edges, Jaccard Index: 0.1086, Weighted Jaccard Index: 0.1192
# dfs ∩ bfs at K=5000: 1019 edges, Jaccard Index: 0.1300, Weighted Jaccard Index: 0.1480
# dfs ∩ bfs at K=6000: 1293 edges, Jaccard Index: 0.1365, Weighted Jaccard Index: 0.1572
# dfs ∩ bfs at K=7000: 1642 edges, Jaccard Index: 0.1473, Weighted Jaccard Index: 0.1676
# dfs ∩ bfs at K=8000: 2039 edges, Jaccard Index: 0.1590, Weighted Jaccard Index: 0.1819
# dfs ∩ bfs at K=9000: 2401 edges, Jaccard Index: 0.1668, Weighted Jaccard Index: 0.1918
# dfs ∩ bfs at K=10000: 2862 edges, Jaccard Index: 0.1795, Weighted Jaccard Index: 0.2060
# dfs ∩ bfs at K=1000: 22 edges, Jaccard Index: 0.0217, Weighted Jaccard Index: 0.0404
# dfs ∩ bfs at K=2000: 76 edges, Jaccard Index: 0.0345, Weighted Jaccard Index: 0.0516
# dfs ∩ bfs at K=3000: 161 edges, Jaccard Index: 0.0472, Weighted Jaccard Index: 0.0578
# dfs ∩ bfs at K=4000: 310 edges, Jaccard Index: 0.0640, Weighted Jaccard Index: 0.0873
# dfs ∩ bfs at K=5000: 424 edges, Jaccard Index: 0.0666, Weighted Jaccard Index: 0.0879
# dfs ∩ bfs at K=6000: 728 edges, Jaccard Index: 0.0950, Weighted Jaccard Index: 0.1092
# dfs ∩ bfs at K=7000: 1000 edges, Jaccard Index: 0.1111, Weighted Jaccard Index: 0.1247
# dfs ∩ bfs at K=8000: 1295 edges, Jaccard Index: 0.1267, Weighted Jaccard Index: 0.1414
# dfs ∩ bfs at K=9000: 1559 edges, Jaccard Index: 0.1358, Weighted Jaccard Index: 0.1504
# dfs ∩ bfs at K=10000: 1847 edges, Jaccard Index: 0.1456, Weighted Jaccard Index: 0.1638
# dfs ∩ bfs at K=1000: 21 edges, Jaccard Index: 0.0178, Weighted Jaccard Index: 0.0264
# dfs ∩ bfs at K=2000: 88 edges, Jaccard Index: 0.0351, Weighted Jaccard Index: 0.0445
# dfs ∩ bfs at K=3000: 175 edges, Jaccard Index: 0.0460, Weighted Jaccard Index: 0.0525
# dfs ∩ bfs at K=4000: 283 edges, Jaccard Index: 0.0550, Weighted Jaccard Index: 0.0669
# dfs ∩ bfs at K=5000: 450 edges, Jaccard Index: 0.0703, Weighted Jaccard Index: 0.0844
# dfs ∩ bfs at K=6000: 599 edges, Jaccard Index: 0.0767, Weighted Jaccard Index: 0.0919
# dfs ∩ bfs at K=7000: 826 edges, Jaccard Index: 0.0901, Weighted Jaccard Index: 0.1064
# dfs ∩ bfs at K=8000: 1143 edges, Jaccard Index: 0.1095, Weighted Jaccard Index: 0.1266
# dfs ∩ bfs at K=9000: 1466 edges, Jaccard Index: 0.1255, Weighted Jaccard Index: 0.1458
# dfs ∩ bfs at K=10000: 1745 edges, Jaccard Index: 0.1351, Weighted Jaccard Index: 0.1553
# dfs ∩ dijkstra at K=1000: 24 edges, Jaccard Index: 0.0214, Weighted Jaccard Index: 0.0239
# dfs ∩ dijkstra at K=2000: 134 edges, Jaccard Index: 0.0484, Weighted Jaccard Index: 0.0518
# dfs ∩ dijkstra at K=3000: 423 edges, Jaccard Index: 0.0961, Weighted Jaccard Index: 0.1089
# dfs ∩ dijkstra at K=4000: 647 edges, Jaccard Index: 0.1075, Weighted Jaccard Index: 0.1187
# dfs ∩ dijkstra at K=5000: 908 edges, Jaccard Index: 0.1192, Weighted Jaccard Index: 0.1308
# dfs ∩ dijkstra at K=6000: 1306 edges, Jaccard Index: 0.1427, Weighted Jaccard Index: 0.1529
# dfs ∩ dijkstra at K=7000: 1712 edges, Jaccard Index: 0.1609, Weighted Jaccard Index: 0.1731
# dfs ∩ dijkstra at K=8000: 2165 edges, Jaccard Index: 0.1786, Weighted Jaccard Index: 0.1892
# dfs ∩ dijkstra at K=9000: 2663 edges, Jaccard Index: 0.1942, Weighted Jaccard Index: 0.2026
# dfs ∩ dijkstra at K=10000: 3309 edges, Jaccard Index: 0.2183, Weighted Jaccard Index: 0.2255
# dfs ∩ dijkstra at K=1000: 11 edges, Jaccard Index: 0.0133, Weighted Jaccard Index: 0.0207
# dfs ∩ dijkstra at K=2000: 54 edges, Jaccard Index: 0.0273, Weighted Jaccard Index: 0.0455
# dfs ∩ dijkstra at K=3000: 148 edges, Jaccard Index: 0.0469, Weighted Jaccard Index: 0.0704
# dfs ∩ dijkstra at K=4000: 264 edges, Jaccard Index: 0.0548, Weighted Jaccard Index: 0.0816
# dfs ∩ dijkstra at K=5000: 419 edges, Jaccard Index: 0.0671, Weighted Jaccard Index: 0.0976
# dfs ∩ dijkstra at K=6000: 637 edges, Jaccard Index: 0.0826, Weighted Jaccard Index: 0.1091
# dfs ∩ dijkstra at K=7000: 899 edges, Jaccard Index: 0.0999, Weighted Jaccard Index: 0.1275
# dfs ∩ dijkstra at K=8000: 1180 edges, Jaccard Index: 0.1155, Weighted Jaccard Index: 0.1445
# dfs ∩ dijkstra at K=9000: 1494 edges, Jaccard Index: 0.1287, Weighted Jaccard Index: 0.1630
# dfs ∩ dijkstra at K=10000: 1818 edges, Jaccard Index: 0.1404, Weighted Jaccard Index: 0.1741
# dfs ∩ dijkstra at K=1000: 0 edges, Jaccard Index: 0.0000, Weighted Jaccard Index: 0.0000
# dfs ∩ dijkstra at K=2000: 36 edges, Jaccard Index: 0.0159, Weighted Jaccard Index: 0.0261
# dfs ∩ dijkstra at K=3000: 124 edges, Jaccard Index: 0.0350, Weighted Jaccard Index: 0.0497
# dfs ∩ dijkstra at K=4000: 236 edges, Jaccard Index: 0.0493, Weighted Jaccard Index: 0.0596
# dfs ∩ dijkstra at K=5000: 422 edges, Jaccard Index: 0.0634, Weighted Jaccard Index: 0.0889
# dfs ∩ dijkstra at K=6000: 627 edges, Jaccard Index: 0.0789, Weighted Jaccard Index: 0.1048
# dfs ∩ dijkstra at K=7000: 867 edges, Jaccard Index: 0.0930, Weighted Jaccard Index: 0.1226
# dfs ∩ dijkstra at K=8000: 1218 edges, Jaccard Index: 0.1151, Weighted Jaccard Index: 0.1420
# dfs ∩ dijkstra at K=9000: 1524 edges, Jaccard Index: 0.1277, Weighted Jaccard Index: 0.1544
# dfs ∩ dijkstra at K=10000: 1856 edges, Jaccard Index: 0.1413, Weighted Jaccard Index: 0.1715
# dfs ∩ mst_prim at K=1000: 32 edges, Jaccard Index: 0.0247, Weighted Jaccard Index: 0.0312
# dfs ∩ mst_prim at K=2000: 144 edges, Jaccard Index: 0.0473, Weighted Jaccard Index: 0.0571
# dfs ∩ mst_prim at K=3000: 390 edges, Jaccard Index: 0.0828, Weighted Jaccard Index: 0.0924
# dfs ∩ mst_prim at K=4000: 594 edges, Jaccard Index: 0.0937, Weighted Jaccard Index: 0.1010
# dfs ∩ mst_prim at K=5000: 875 edges, Jaccard Index: 0.1102, Weighted Jaccard Index: 0.1190
# dfs ∩ mst_prim at K=6000: 1193 edges, Jaccard Index: 0.1255, Weighted Jaccard Index: 0.1323
# dfs ∩ mst_prim at K=7000: 1565 edges, Jaccard Index: 0.1413, Weighted Jaccard Index: 0.1497
# dfs ∩ mst_prim at K=8000: 1948 edges, Jaccard Index: 0.1545, Weighted Jaccard Index: 0.1661
# dfs ∩ mst_prim at K=9000: 2327 edges, Jaccard Index: 0.1642, Weighted Jaccard Index: 0.1750
# dfs ∩ mst_prim at K=10000: 2784 edges, Jaccard Index: 0.1775, Weighted Jaccard Index: 0.1880
# dfs ∩ mst_prim at K=1000: 10 edges, Jaccard Index: 0.0108, Weighted Jaccard Index: 0.0095
# dfs ∩ mst_prim at K=2000: 53 edges, Jaccard Index: 0.0251, Weighted Jaccard Index: 0.0345
# dfs ∩ mst_prim at K=3000: 131 edges, Jaccard Index: 0.0394, Weighted Jaccard Index: 0.0505
# dfs ∩ mst_prim at K=4000: 241 edges, Jaccard Index: 0.0508, Weighted Jaccard Index: 0.0661
# dfs ∩ mst_prim at K=5000: 382 edges, Jaccard Index: 0.0612, Weighted Jaccard Index: 0.0826
# dfs ∩ mst_prim at K=6000: 567 edges, Jaccard Index: 0.0733, Weighted Jaccard Index: 0.0978
# dfs ∩ mst_prim at K=7000: 768 edges, Jaccard Index: 0.0849, Weighted Jaccard Index: 0.1110
# dfs ∩ mst_prim at K=8000: 969 edges, Jaccard Index: 0.0939, Weighted Jaccard Index: 0.1212
# dfs ∩ mst_prim at K=9000: 1221 edges, Jaccard Index: 0.1050, Weighted Jaccard Index: 0.1339
# dfs ∩ mst_prim at K=10000: 1529 edges, Jaccard Index: 0.1194, Weighted Jaccard Index: 0.1498
# dfs ∩ mst_prim at K=1000: 5 edges, Jaccard Index: 0.0048, Weighted Jaccard Index: 0.0043
# dfs ∩ mst_prim at K=2000: 70 edges, Jaccard Index: 0.0287, Weighted Jaccard Index: 0.0384
# dfs ∩ mst_prim at K=3000: 117 edges, Jaccard Index: 0.0310, Weighted Jaccard Index: 0.0431
# dfs ∩ mst_prim at K=4000: 201 edges, Jaccard Index: 0.0392, Weighted Jaccard Index: 0.0519
# dfs ∩ mst_prim at K=5000: 393 edges, Jaccard Index: 0.0617, Weighted Jaccard Index: 0.0720
# dfs ∩ mst_prim at K=6000: 548 edges, Jaccard Index: 0.0691, Weighted Jaccard Index: 0.0846
# dfs ∩ mst_prim at K=7000: 721 edges, Jaccard Index: 0.0776, Weighted Jaccard Index: 0.0950
# dfs ∩ mst_prim at K=8000: 901 edges, Jaccard Index: 0.0836, Weighted Jaccard Index: 0.1024
# dfs ∩ mst_prim at K=9000: 1127 edges, Jaccard Index: 0.0926, Weighted Jaccard Index: 0.1148
# dfs ∩ mst_prim at K=10000: 1388 edges, Jaccard Index: 0.1035, Weighted Jaccard Index: 0.1253
# dfs ∩ bellman_ford at K=1000: 17 edges, Jaccard Index: 0.0140, Weighted Jaccard Index: 0.0154
# dfs ∩ bellman_ford at K=2000: 106 edges, Jaccard Index: 0.0366, Weighted Jaccard Index: 0.0403
# dfs ∩ bellman_ford at K=3000: 304 edges, Jaccard Index: 0.0651, Weighted Jaccard Index: 0.0728
# dfs ∩ bellman_ford at K=4000: 503 edges, Jaccard Index: 0.0793, Weighted Jaccard Index: 0.0856
# dfs ∩ bellman_ford at K=5000: 719 edges, Jaccard Index: 0.0899, Weighted Jaccard Index: 0.0962
# dfs ∩ bellman_ford at K=6000: 1046 edges, Jaccard Index: 0.1089, Weighted Jaccard Index: 0.1152
# dfs ∩ bellman_ford at K=7000: 1399 edges, Jaccard Index: 0.1241, Weighted Jaccard Index: 0.1348
# dfs ∩ bellman_ford at K=8000: 1731 edges, Jaccard Index: 0.1339, Weighted Jaccard Index: 0.1444
# dfs ∩ bellman_ford at K=9000: 2119 edges, Jaccard Index: 0.1457, Weighted Jaccard Index: 0.1585
# dfs ∩ bellman_ford at K=10000: 2637 edges, Jaccard Index: 0.1641, Weighted Jaccard Index: 0.1746
# dfs ∩ bellman_ford at K=1000: 9 edges, Jaccard Index: 0.0120, Weighted Jaccard Index: 0.0190
# dfs ∩ bellman_ford at K=2000: 37 edges, Jaccard Index: 0.0192, Weighted Jaccard Index: 0.0287
# dfs ∩ bellman_ford at K=3000: 81 edges, Jaccard Index: 0.0255, Weighted Jaccard Index: 0.0322
# dfs ∩ bellman_ford at K=4000: 166 edges, Jaccard Index: 0.0344, Weighted Jaccard Index: 0.0435
# dfs ∩ bellman_ford at K=5000: 282 edges, Jaccard Index: 0.0443, Weighted Jaccard Index: 0.0568
# dfs ∩ bellman_ford at K=6000: 466 edges, Jaccard Index: 0.0598, Weighted Jaccard Index: 0.0716
# dfs ∩ bellman_ford at K=7000: 671 edges, Jaccard Index: 0.0719, Weighted Jaccard Index: 0.0830
# dfs ∩ bellman_ford at K=8000: 879 edges, Jaccard Index: 0.0822, Weighted Jaccard Index: 0.0934
# dfs ∩ bellman_ford at K=9000: 1083 edges, Jaccard Index: 0.0898, Weighted Jaccard Index: 0.1027
# dfs ∩ bellman_ford at K=10000: 1432 edges, Jaccard Index: 0.1071, Weighted Jaccard Index: 0.1207
# dfs ∩ bellman_ford at K=1000: 0 edges, Jaccard Index: 0.0000, Weighted Jaccard Index: 0.0000
# dfs ∩ bellman_ford at K=2000: 24 edges, Jaccard Index: 0.0108, Weighted Jaccard Index: 0.0158
# dfs ∩ bellman_ford at K=3000: 85 edges, Jaccard Index: 0.0231, Weighted Jaccard Index: 0.0332
# dfs ∩ bellman_ford at K=4000: 168 edges, Jaccard Index: 0.0325, Weighted Jaccard Index: 0.0410
# dfs ∩ bellman_ford at K=5000: 298 edges, Jaccard Index: 0.0448, Weighted Jaccard Index: 0.0526
# dfs ∩ bellman_ford at K=6000: 460 edges, Jaccard Index: 0.0567, Weighted Jaccard Index: 0.0662
# dfs ∩ bellman_ford at K=7000: 640 edges, Jaccard Index: 0.0663, Weighted Jaccard Index: 0.0784
# dfs ∩ bellman_ford at K=8000: 911 edges, Jaccard Index: 0.0821, Weighted Jaccard Index: 0.0946
# dfs ∩ bellman_ford at K=9000: 1180 edges, Jaccard Index: 0.0949, Weighted Jaccard Index: 0.1085
# dfs ∩ bellman_ford at K=10000: 1466 edges, Jaccard Index: 0.1074, Weighted Jaccard Index: 0.1200
# dfs ∩ articulation_points at K=1000: 54 edges, Jaccard Index: 0.0395, Weighted Jaccard Index: 0.0242
# dfs ∩ articulation_points at K=2000: 218 edges, Jaccard Index: 0.0735, Weighted Jaccard Index: 0.0648
# dfs ∩ articulation_points at K=3000: 543 edges, Jaccard Index: 0.1176, Weighted Jaccard Index: 0.1155
# dfs ∩ articulation_points at K=4000: 852 edges, Jaccard Index: 0.1369, Weighted Jaccard Index: 0.1333
# dfs ∩ articulation_points at K=5000: 1175 edges, Jaccard Index: 0.1527, Weighted Jaccard Index: 0.1507
# dfs ∩ articulation_points at K=6000: 1558 edges, Jaccard Index: 0.1687, Weighted Jaccard Index: 0.1659
# dfs ∩ articulation_points at K=7000: 1889 edges, Jaccard Index: 0.1743, Weighted Jaccard Index: 0.1754
# dfs ∩ articulation_points at K=8000: 2369 edges, Jaccard Index: 0.1938, Weighted Jaccard Index: 0.1984
# dfs ∩ articulation_points at K=9000: 2816 edges, Jaccard Index: 0.2062, Weighted Jaccard Index: 0.2066
# dfs ∩ articulation_points at K=10000: 3352 edges, Jaccard Index: 0.2222, Weighted Jaccard Index: 0.2257
# dfs ∩ articulation_points at K=1000: 29 edges, Jaccard Index: 0.0255, Weighted Jaccard Index: 0.0397
# dfs ∩ articulation_points at K=2000: 75 edges, Jaccard Index: 0.0304, Weighted Jaccard Index: 0.0467
# dfs ∩ articulation_points at K=3000: 142 edges, Jaccard Index: 0.0373, Weighted Jaccard Index: 0.0522
# dfs ∩ articulation_points at K=4000: 257 edges, Jaccard Index: 0.0486, Weighted Jaccard Index: 0.0646
# dfs ∩ articulation_points at K=5000: 408 edges, Jaccard Index: 0.0598, Weighted Jaccard Index: 0.0773
# dfs ∩ articulation_points at K=6000: 607 edges, Jaccard Index: 0.0733, Weighted Jaccard Index: 0.0925
# dfs ∩ articulation_points at K=7000: 869 edges, Jaccard Index: 0.0902, Weighted Jaccard Index: 0.1121
# dfs ∩ articulation_points at K=8000: 1141 edges, Jaccard Index: 0.1044, Weighted Jaccard Index: 0.1320
# dfs ∩ articulation_points at K=9000: 1442 edges, Jaccard Index: 0.1182, Weighted Jaccard Index: 0.1473
# dfs ∩ articulation_points at K=10000: 1762 edges, Jaccard Index: 0.1311, Weighted Jaccard Index: 0.1589
# dfs ∩ articulation_points at K=1000: 36 edges, Jaccard Index: 0.0302, Weighted Jaccard Index: 0.0269
# dfs ∩ articulation_points at K=2000: 92 edges, Jaccard Index: 0.0357, Weighted Jaccard Index: 0.0362
# dfs ∩ articulation_points at K=3000: 231 edges, Jaccard Index: 0.0591, Weighted Jaccard Index: 0.0622
# dfs ∩ articulation_points at K=4000: 375 edges, Jaccard Index: 0.0721, Weighted Jaccard Index: 0.0784
# dfs ∩ articulation_points at K=5000: 549 edges, Jaccard Index: 0.0847, Weighted Jaccard Index: 0.0934
# dfs ∩ articulation_points at K=6000: 821 edges, Jaccard Index: 0.1037, Weighted Jaccard Index: 0.1118
# dfs ∩ articulation_points at K=7000: 1113 edges, Jaccard Index: 0.1188, Weighted Jaccard Index: 0.1293
# dfs ∩ articulation_points at K=8000: 1464 edges, Jaccard Index: 0.1374, Weighted Jaccard Index: 0.1514
# dfs ∩ articulation_points at K=9000: 1782 edges, Jaccard Index: 0.1487, Weighted Jaccard Index: 0.1607
# dfs ∩ articulation_points at K=10000: 2136 edges, Jaccard Index: 0.1614, Weighted Jaccard Index: 0.1724
# dfs ∩ bridges at K=1000: 53 edges, Jaccard Index: 0.0463, Weighted Jaccard Index: 0.0568
# dfs ∩ bridges at K=2000: 256 edges, Jaccard Index: 0.0976, Weighted Jaccard Index: 0.1134
# dfs ∩ bridges at K=3000: 518 edges, Jaccard Index: 0.1227, Weighted Jaccard Index: 0.1397
# dfs ∩ bridges at K=4000: 808 edges, Jaccard Index: 0.1394, Weighted Jaccard Index: 0.1576
# dfs ∩ bridges at K=5000: 1150 edges, Jaccard Index: 0.1567, Weighted Jaccard Index: 0.1694
# dfs ∩ bridges at K=6000: 1543 edges, Jaccard Index: 0.1756, Weighted Jaccard Index: 0.1935
# dfs ∩ bridges at K=7000: 2035 edges, Jaccard Index: 0.1972, Weighted Jaccard Index: 0.2187
# dfs ∩ bridges at K=8000: 2592 edges, Jaccard Index: 0.2213, Weighted Jaccard Index: 0.2452
# dfs ∩ bridges at K=9000: 3113 edges, Jaccard Index: 0.2378, Weighted Jaccard Index: 0.2602
# dfs ∩ bridges at K=10000: 3748 edges, Jaccard Index: 0.2580, Weighted Jaccard Index: 0.2752
# dfs ∩ bridges at K=1000: 19 edges, Jaccard Index: 0.0181, Weighted Jaccard Index: 0.0281
# dfs ∩ bridges at K=2000: 74 edges, Jaccard Index: 0.0324, Weighted Jaccard Index: 0.0509
# dfs ∩ bridges at K=3000: 191 edges, Jaccard Index: 0.0554, Weighted Jaccard Index: 0.0769
# dfs ∩ bridges at K=4000: 359 edges, Jaccard Index: 0.0728, Weighted Jaccard Index: 0.0947
# dfs ∩ bridges at K=5000: 590 edges, Jaccard Index: 0.0912, Weighted Jaccard Index: 0.1102
# dfs ∩ bridges at K=6000: 954 edges, Jaccard Index: 0.1237, Weighted Jaccard Index: 0.1482
# dfs ∩ bridges at K=7000: 1309 edges, Jaccard Index: 0.1468, Weighted Jaccard Index: 0.1723
# dfs ∩ bridges at K=8000: 1613 edges, Jaccard Index: 0.1587, Weighted Jaccard Index: 0.1940
# dfs ∩ bridges at K=9000: 1930 edges, Jaccard Index: 0.1675, Weighted Jaccard Index: 0.2032
# dfs ∩ bridges at K=10000: 2303 edges, Jaccard Index: 0.1823, Weighted Jaccard Index: 0.2200
# dfs ∩ bridges at K=1000: 2 edges, Jaccard Index: 0.0028, Weighted Jaccard Index: 0.0043
# dfs ∩ bridges at K=2000: 186 edges, Jaccard Index: 0.0828, Weighted Jaccard Index: 0.1204
# dfs ∩ bridges at K=3000: 350 edges, Jaccard Index: 0.1021, Weighted Jaccard Index: 0.1364
# dfs ∩ bridges at K=4000: 571 edges, Jaccard Index: 0.1236, Weighted Jaccard Index: 0.1631
# dfs ∩ bridges at K=5000: 806 edges, Jaccard Index: 0.1353, Weighted Jaccard Index: 0.1789
# dfs ∩ bridges at K=6000: 1128 edges, Jaccard Index: 0.1561, Weighted Jaccard Index: 0.1938
# dfs ∩ bridges at K=7000: 1418 edges, Jaccard Index: 0.1663, Weighted Jaccard Index: 0.1997
# dfs ∩ bridges at K=8000: 1917 edges, Jaccard Index: 0.1978, Weighted Jaccard Index: 0.2233
# dfs ∩ bridges at K=9000: 2315 edges, Jaccard Index: 0.2107, Weighted Jaccard Index: 0.2361
# dfs ∩ bridges at K=10000: 2703 edges, Jaccard Index: 0.2240, Weighted Jaccard Index: 0.2499
# dijkstra ∩ bfs at K=1000: 49 edges, Jaccard Index: 0.0395, Weighted Jaccard Index: 0.0411
# dijkstra ∩ bfs at K=2000: 124 edges, Jaccard Index: 0.0431, Weighted Jaccard Index: 0.0494
# dijkstra ∩ bfs at K=3000: 289 edges, Jaccard Index: 0.0637, Weighted Jaccard Index: 0.0706
# dijkstra ∩ bfs at K=4000: 486 edges, Jaccard Index: 0.0789, Weighted Jaccard Index: 0.0861
# dijkstra ∩ bfs at K=5000: 717 edges, Jaccard Index: 0.0919, Weighted Jaccard Index: 0.1010
# dijkstra ∩ bfs at K=6000: 976 edges, Jaccard Index: 0.1025, Weighted Jaccard Index: 0.1136
# dijkstra ∩ bfs at K=7000: 1286 edges, Jaccard Index: 0.1154, Weighted Jaccard Index: 0.1290
# dijkstra ∩ bfs at K=8000: 1618 edges, Jaccard Index: 0.1254, Weighted Jaccard Index: 0.1407
# dijkstra ∩ bfs at K=9000: 2015 edges, Jaccard Index: 0.1384, Weighted Jaccard Index: 0.1536
# dijkstra ∩ bfs at K=10000: 2471 edges, Jaccard Index: 0.1528, Weighted Jaccard Index: 0.1664
# dijkstra ∩ bfs at K=1000: 3 edges, Jaccard Index: 0.0031, Weighted Jaccard Index: 0.0053
# dijkstra ∩ bfs at K=2000: 34 edges, Jaccard Index: 0.0153, Weighted Jaccard Index: 0.0176
# dijkstra ∩ bfs at K=3000: 88 edges, Jaccard Index: 0.0252, Weighted Jaccard Index: 0.0302
# dijkstra ∩ bfs at K=4000: 220 edges, Jaccard Index: 0.0437, Weighted Jaccard Index: 0.0540
# dijkstra ∩ bfs at K=5000: 348 edges, Jaccard Index: 0.0543, Weighted Jaccard Index: 0.0671
# dijkstra ∩ bfs at K=6000: 466 edges, Jaccard Index: 0.0589, Weighted Jaccard Index: 0.0742
# dijkstra ∩ bfs at K=7000: 633 edges, Jaccard Index: 0.0678, Weighted Jaccard Index: 0.0873
# dijkstra ∩ bfs at K=8000: 814 edges, Jaccard Index: 0.0769, Weighted Jaccard Index: 0.1004
# dijkstra ∩ bfs at K=9000: 1097 edges, Jaccard Index: 0.0919, Weighted Jaccard Index: 0.1174
# dijkstra ∩ bfs at K=10000: 1354 edges, Jaccard Index: 0.1017, Weighted Jaccard Index: 0.1292
# dijkstra ∩ bfs at K=1000: 3 edges, Jaccard Index: 0.0032, Weighted Jaccard Index: 0.0021
# dijkstra ∩ bfs at K=2000: 30 edges, Jaccard Index: 0.0152, Weighted Jaccard Index: 0.0216
# dijkstra ∩ bfs at K=3000: 104 edges, Jaccard Index: 0.0332, Weighted Jaccard Index: 0.0439
# dijkstra ∩ bfs at K=4000: 174 edges, Jaccard Index: 0.0401, Weighted Jaccard Index: 0.0529
# dijkstra ∩ bfs at K=5000: 295 edges, Jaccard Index: 0.0475, Weighted Jaccard Index: 0.0602
# dijkstra ∩ bfs at K=6000: 431 edges, Jaccard Index: 0.0575, Weighted Jaccard Index: 0.0724
# dijkstra ∩ bfs at K=7000: 623 edges, Jaccard Index: 0.0705, Weighted Jaccard Index: 0.0903
# dijkstra ∩ bfs at K=8000: 809 edges, Jaccard Index: 0.0793, Weighted Jaccard Index: 0.1032
# dijkstra ∩ bfs at K=9000: 1049 edges, Jaccard Index: 0.0909, Weighted Jaccard Index: 0.1152
# dijkstra ∩ bfs at K=10000: 1255 edges, Jaccard Index: 0.0975, Weighted Jaccard Index: 0.1218
# dijkstra ∩ dfs at K=1000: 24 edges, Jaccard Index: 0.0214, Weighted Jaccard Index: 0.0239
# dijkstra ∩ dfs at K=2000: 134 edges, Jaccard Index: 0.0484, Weighted Jaccard Index: 0.0518
# dijkstra ∩ dfs at K=3000: 423 edges, Jaccard Index: 0.0961, Weighted Jaccard Index: 0.1089
# dijkstra ∩ dfs at K=4000: 647 edges, Jaccard Index: 0.1075, Weighted Jaccard Index: 0.1187
# dijkstra ∩ dfs at K=5000: 908 edges, Jaccard Index: 0.1192, Weighted Jaccard Index: 0.1308
# dijkstra ∩ dfs at K=6000: 1306 edges, Jaccard Index: 0.1427, Weighted Jaccard Index: 0.1529
# dijkstra ∩ dfs at K=7000: 1712 edges, Jaccard Index: 0.1609, Weighted Jaccard Index: 0.1731
# dijkstra ∩ dfs at K=8000: 2165 edges, Jaccard Index: 0.1786, Weighted Jaccard Index: 0.1892
# dijkstra ∩ dfs at K=9000: 2663 edges, Jaccard Index: 0.1942, Weighted Jaccard Index: 0.2026
# dijkstra ∩ dfs at K=10000: 3309 edges, Jaccard Index: 0.2183, Weighted Jaccard Index: 0.2255
# dijkstra ∩ dfs at K=1000: 11 edges, Jaccard Index: 0.0133, Weighted Jaccard Index: 0.0207
# dijkstra ∩ dfs at K=2000: 54 edges, Jaccard Index: 0.0273, Weighted Jaccard Index: 0.0455
# dijkstra ∩ dfs at K=3000: 148 edges, Jaccard Index: 0.0469, Weighted Jaccard Index: 0.0704
# dijkstra ∩ dfs at K=4000: 264 edges, Jaccard Index: 0.0548, Weighted Jaccard Index: 0.0816
# dijkstra ∩ dfs at K=5000: 419 edges, Jaccard Index: 0.0671, Weighted Jaccard Index: 0.0976
# dijkstra ∩ dfs at K=6000: 637 edges, Jaccard Index: 0.0826, Weighted Jaccard Index: 0.1091
# dijkstra ∩ dfs at K=7000: 899 edges, Jaccard Index: 0.0999, Weighted Jaccard Index: 0.1275
# dijkstra ∩ dfs at K=8000: 1180 edges, Jaccard Index: 0.1155, Weighted Jaccard Index: 0.1445
# dijkstra ∩ dfs at K=9000: 1494 edges, Jaccard Index: 0.1287, Weighted Jaccard Index: 0.1630
# dijkstra ∩ dfs at K=10000: 1818 edges, Jaccard Index: 0.1404, Weighted Jaccard Index: 0.1741
# dijkstra ∩ dfs at K=1000: 0 edges, Jaccard Index: 0.0000, Weighted Jaccard Index: 0.0000
# dijkstra ∩ dfs at K=2000: 36 edges, Jaccard Index: 0.0159, Weighted Jaccard Index: 0.0261
# dijkstra ∩ dfs at K=3000: 124 edges, Jaccard Index: 0.0350, Weighted Jaccard Index: 0.0497
# dijkstra ∩ dfs at K=4000: 236 edges, Jaccard Index: 0.0493, Weighted Jaccard Index: 0.0596
# dijkstra ∩ dfs at K=5000: 422 edges, Jaccard Index: 0.0634, Weighted Jaccard Index: 0.0889
# dijkstra ∩ dfs at K=6000: 627 edges, Jaccard Index: 0.0789, Weighted Jaccard Index: 0.1048
# dijkstra ∩ dfs at K=7000: 867 edges, Jaccard Index: 0.0930, Weighted Jaccard Index: 0.1226
# dijkstra ∩ dfs at K=8000: 1218 edges, Jaccard Index: 0.1151, Weighted Jaccard Index: 0.1420
# dijkstra ∩ dfs at K=9000: 1524 edges, Jaccard Index: 0.1277, Weighted Jaccard Index: 0.1544
# dijkstra ∩ dfs at K=10000: 1856 edges, Jaccard Index: 0.1413, Weighted Jaccard Index: 0.1715
# dijkstra ∩ mst_prim at K=1000: 14 edges, Jaccard Index: 0.0114, Weighted Jaccard Index: 0.0193
# dijkstra ∩ mst_prim at K=2000: 149 edges, Jaccard Index: 0.0507, Weighted Jaccard Index: 0.0607
# dijkstra ∩ mst_prim at K=3000: 398 edges, Jaccard Index: 0.0884, Weighted Jaccard Index: 0.1028
# dijkstra ∩ mst_prim at K=4000: 623 edges, Jaccard Index: 0.1035, Weighted Jaccard Index: 0.1200
# dijkstra ∩ mst_prim at K=5000: 945 edges, Jaccard Index: 0.1254, Weighted Jaccard Index: 0.1464
# dijkstra ∩ mst_prim at K=6000: 1298 edges, Jaccard Index: 0.1422, Weighted Jaccard Index: 0.1636
# dijkstra ∩ mst_prim at K=7000: 1639 edges, Jaccard Index: 0.1540, Weighted Jaccard Index: 0.1718
# dijkstra ∩ mst_prim at K=8000: 2050 edges, Jaccard Index: 0.1686, Weighted Jaccard Index: 0.1894
# dijkstra ∩ mst_prim at K=9000: 2554 edges, Jaccard Index: 0.1861, Weighted Jaccard Index: 0.2093
# dijkstra ∩ mst_prim at K=10000: 3091 edges, Jaccard Index: 0.2031, Weighted Jaccard Index: 0.2304
# dijkstra ∩ mst_prim at K=1000: 27 edges, Jaccard Index: 0.0320, Weighted Jaccard Index: 0.0414
# dijkstra ∩ mst_prim at K=2000: 114 edges, Jaccard Index: 0.0562, Weighted Jaccard Index: 0.0780
# dijkstra ∩ mst_prim at K=3000: 211 edges, Jaccard Index: 0.0647, Weighted Jaccard Index: 0.0905
# dijkstra ∩ mst_prim at K=4000: 340 edges, Jaccard Index: 0.0715, Weighted Jaccard Index: 0.1030
# dijkstra ∩ mst_prim at K=5000: 533 edges, Jaccard Index: 0.0881, Weighted Jaccard Index: 0.1245
# dijkstra ∩ mst_prim at K=6000: 903 edges, Jaccard Index: 0.1221, Weighted Jaccard Index: 0.1554
# dijkstra ∩ mst_prim at K=7000: 1206 edges, Jaccard Index: 0.1408, Weighted Jaccard Index: 0.1751
# dijkstra ∩ mst_prim at K=8000: 1502 edges, Jaccard Index: 0.1551, Weighted Jaccard Index: 0.1921
# dijkstra ∩ mst_prim at K=9000: 1832 edges, Jaccard Index: 0.1663, Weighted Jaccard Index: 0.2007
# dijkstra ∩ mst_prim at K=10000: 2220 edges, Jaccard Index: 0.1813, Weighted Jaccard Index: 0.2175
# dijkstra ∩ mst_prim at K=1000: 26 edges, Jaccard Index: 0.0341, Weighted Jaccard Index: 0.0460
# dijkstra ∩ mst_prim at K=2000: 65 edges, Jaccard Index: 0.0351, Weighted Jaccard Index: 0.0493
# dijkstra ∩ mst_prim at K=3000: 189 edges, Jaccard Index: 0.0640, Weighted Jaccard Index: 0.0851
# dijkstra ∩ mst_prim at K=4000: 299 edges, Jaccard Index: 0.0727, Weighted Jaccard Index: 0.0951
# dijkstra ∩ mst_prim at K=5000: 546 edges, Jaccard Index: 0.0930, Weighted Jaccard Index: 0.1159
# dijkstra ∩ mst_prim at K=6000: 811 edges, Jaccard Index: 0.1128, Weighted Jaccard Index: 0.1417
# dijkstra ∩ mst_prim at K=7000: 1093 edges, Jaccard Index: 0.1303, Weighted Jaccard Index: 0.1692
# dijkstra ∩ mst_prim at K=8000: 1457 edges, Jaccard Index: 0.1508, Weighted Jaccard Index: 0.1970
# dijkstra ∩ mst_prim at K=9000: 1794 edges, Jaccard Index: 0.1640, Weighted Jaccard Index: 0.2105
# dijkstra ∩ mst_prim at K=10000: 2125 edges, Jaccard Index: 0.1749, Weighted Jaccard Index: 0.2212
# dijkstra ∩ bellman_ford at K=1000: 62 edges, Jaccard Index: 0.0574, Weighted Jaccard Index: 0.0689
# dijkstra ∩ bellman_ford at K=2000: 277 edges, Jaccard Index: 0.1056, Weighted Jaccard Index: 0.1144
# dijkstra ∩ bellman_ford at K=3000: 563 edges, Jaccard Index: 0.1337, Weighted Jaccard Index: 0.1464
# dijkstra ∩ bellman_ford at K=4000: 875 edges, Jaccard Index: 0.1542, Weighted Jaccard Index: 0.1732
# dijkstra ∩ bellman_ford at K=5000: 1252 edges, Jaccard Index: 0.1755, Weighted Jaccard Index: 0.1991
# dijkstra ∩ bellman_ford at K=6000: 1656 edges, Jaccard Index: 0.1899, Weighted Jaccard Index: 0.2165
# dijkstra ∩ bellman_ford at K=7000: 2031 edges, Jaccard Index: 0.1975, Weighted Jaccard Index: 0.2276
# dijkstra ∩ bellman_ford at K=8000: 2484 edges, Jaccard Index: 0.2100, Weighted Jaccard Index: 0.2372
# dijkstra ∩ bellman_ford at K=9000: 2957 edges, Jaccard Index: 0.2194, Weighted Jaccard Index: 0.2473
# dijkstra ∩ bellman_ford at K=10000: 3459 edges, Jaccard Index: 0.2292, Weighted Jaccard Index: 0.2532
# dijkstra ∩ bellman_ford at K=1000: 57 edges, Jaccard Index: 0.0900, Weighted Jaccard Index: 0.1429
# dijkstra ∩ bellman_ford at K=2000: 223 edges, Jaccard Index: 0.1297, Weighted Jaccard Index: 0.1661
# dijkstra ∩ bellman_ford at K=3000: 441 edges, Jaccard Index: 0.1560, Weighted Jaccard Index: 0.1816
# dijkstra ∩ bellman_ford at K=4000: 720 edges, Jaccard Index: 0.1645, Weighted Jaccard Index: 0.1815
# dijkstra ∩ bellman_ford at K=5000: 928 edges, Jaccard Index: 0.1634, Weighted Jaccard Index: 0.1826
# dijkstra ∩ bellman_ford at K=6000: 1223 edges, Jaccard Index: 0.1741, Weighted Jaccard Index: 0.1961
# dijkstra ∩ bellman_ford at K=7000: 1554 edges, Jaccard Index: 0.1846, Weighted Jaccard Index: 0.2120
# dijkstra ∩ bellman_ford at K=8000: 1861 edges, Jaccard Index: 0.1939, Weighted Jaccard Index: 0.2223
# dijkstra ∩ bellman_ford at K=9000: 2220 edges, Jaccard Index: 0.2034, Weighted Jaccard Index: 0.2296
# dijkstra ∩ bellman_ford at K=10000: 2762 edges, Jaccard Index: 0.2269, Weighted Jaccard Index: 0.2482
# dijkstra ∩ bellman_ford at K=1000: 44 edges, Jaccard Index: 0.0737, Weighted Jaccard Index: 0.1110
# dijkstra ∩ bellman_ford at K=2000: 140 edges, Jaccard Index: 0.0921, Weighted Jaccard Index: 0.1087
# dijkstra ∩ bellman_ford at K=3000: 444 edges, Jaccard Index: 0.1722, Weighted Jaccard Index: 0.1877
# dijkstra ∩ bellman_ford at K=4000: 671 edges, Jaccard Index: 0.1786, Weighted Jaccard Index: 0.1974
# dijkstra ∩ bellman_ford at K=5000: 1052 edges, Jaccard Index: 0.1893, Weighted Jaccard Index: 0.2050
# dijkstra ∩ bellman_ford at K=6000: 1384 edges, Jaccard Index: 0.2060, Weighted Jaccard Index: 0.2192
# dijkstra ∩ bellman_ford at K=7000: 1723 edges, Jaccard Index: 0.2143, Weighted Jaccard Index: 0.2251
# dijkstra ∩ bellman_ford at K=8000: 2157 edges, Jaccard Index: 0.2321, Weighted Jaccard Index: 0.2460
# dijkstra ∩ bellman_ford at K=9000: 2523 edges, Jaccard Index: 0.2395, Weighted Jaccard Index: 0.2571
# dijkstra ∩ bellman_ford at K=10000: 2882 edges, Jaccard Index: 0.2461, Weighted Jaccard Index: 0.2638
# dijkstra ∩ articulation_points at K=1000: 35 edges, Jaccard Index: 0.0270, Weighted Jaccard Index: 0.0329
# dijkstra ∩ articulation_points at K=2000: 166 edges, Jaccard Index: 0.0569, Weighted Jaccard Index: 0.0663
# dijkstra ∩ articulation_points at K=3000: 352 edges, Jaccard Index: 0.0764, Weighted Jaccard Index: 0.0922
# dijkstra ∩ articulation_points at K=4000: 556 edges, Jaccard Index: 0.0893, Weighted Jaccard Index: 0.1043
# dijkstra ∩ articulation_points at K=5000: 866 edges, Jaccard Index: 0.1129, Weighted Jaccard Index: 0.1282
# dijkstra ∩ articulation_points at K=6000: 1204 edges, Jaccard Index: 0.1291, Weighted Jaccard Index: 0.1409
# dijkstra ∩ articulation_points at K=7000: 1500 edges, Jaccard Index: 0.1380, Weighted Jaccard Index: 0.1512
# dijkstra ∩ articulation_points at K=8000: 1894 edges, Jaccard Index: 0.1533, Weighted Jaccard Index: 0.1645
# dijkstra ∩ articulation_points at K=9000: 2292 edges, Jaccard Index: 0.1643, Weighted Jaccard Index: 0.1735
# dijkstra ∩ articulation_points at K=10000: 2780 edges, Jaccard Index: 0.1794, Weighted Jaccard Index: 0.1867
# dijkstra ∩ articulation_points at K=1000: 14 edges, Jaccard Index: 0.0129, Weighted Jaccard Index: 0.0181
# dijkstra ∩ articulation_points at K=2000: 47 edges, Jaccard Index: 0.0190, Weighted Jaccard Index: 0.0305
# dijkstra ∩ articulation_points at K=3000: 99 edges, Jaccard Index: 0.0256, Weighted Jaccard Index: 0.0383
# dijkstra ∩ articulation_points at K=4000: 183 edges, Jaccard Index: 0.0335, Weighted Jaccard Index: 0.0522
# dijkstra ∩ articulation_points at K=5000: 351 edges, Jaccard Index: 0.0513, Weighted Jaccard Index: 0.0789
# dijkstra ∩ articulation_points at K=6000: 508 edges, Jaccard Index: 0.0607, Weighted Jaccard Index: 0.0901
# dijkstra ∩ articulation_points at K=7000: 687 edges, Jaccard Index: 0.0702, Weighted Jaccard Index: 0.1012
# dijkstra ∩ articulation_points at K=8000: 874 edges, Jaccard Index: 0.0788, Weighted Jaccard Index: 0.1108
# dijkstra ∩ articulation_points at K=9000: 1116 edges, Jaccard Index: 0.0891, Weighted Jaccard Index: 0.1197
# dijkstra ∩ articulation_points at K=10000: 1402 edges, Jaccard Index: 0.1006, Weighted Jaccard Index: 0.1306
# dijkstra ∩ articulation_points at K=1000: 9 edges, Jaccard Index: 0.0094, Weighted Jaccard Index: 0.0125
# dijkstra ∩ articulation_points at K=2000: 51 edges, Jaccard Index: 0.0252, Weighted Jaccard Index: 0.0394
# dijkstra ∩ articulation_points at K=3000: 128 edges, Jaccard Index: 0.0392, Weighted Jaccard Index: 0.0583
# dijkstra ∩ articulation_points at K=4000: 233 edges, Jaccard Index: 0.0526, Weighted Jaccard Index: 0.0701
# dijkstra ∩ articulation_points at K=5000: 393 edges, Jaccard Index: 0.0625, Weighted Jaccard Index: 0.0820
# dijkstra ∩ articulation_points at K=6000: 613 edges, Jaccard Index: 0.0801, Weighted Jaccard Index: 0.1025
# dijkstra ∩ articulation_points at K=7000: 815 edges, Jaccard Index: 0.0892, Weighted Jaccard Index: 0.1123
# dijkstra ∩ articulation_points at K=8000: 1045 edges, Jaccard Index: 0.0994, Weighted Jaccard Index: 0.1213
# dijkstra ∩ articulation_points at K=9000: 1358 edges, Jaccard Index: 0.1146, Weighted Jaccard Index: 0.1379
# dijkstra ∩ articulation_points at K=10000: 1657 edges, Jaccard Index: 0.1257, Weighted Jaccard Index: 0.1469
# ...
# bridges ∩ bfs at K=6000: 697 edges, Jaccard Index: 0.0870, Weighted Jaccard Index: 0.0983
# bridges ∩ bfs at K=7000: 875 edges, Jaccard Index: 0.0929, Weighted Jaccard Index: 0.1082
# bridges ∩ bfs at K=8000: 1123 edges, Jaccard Index: 0.1053, Weighted Jaccard Index: 0.1268
# bridges ∩ bfs at K=9000: 1310 edges, Jaccard Index: 0.1085, Weighted Jaccard Index: 0.1344
# bridges ∩ bfs at K=10000: 1575 edges, Jaccard Index: 0.1188, Weighted Jaccard Index: 0.1449
# bridges ∩ bfs at K=1000: 16 edges, Jaccard Index: 0.0256, Weighted Jaccard Index: 0.0221
# bridges ∩ bfs at K=2000: 55 edges, Jaccard Index: 0.0265, Weighted Jaccard Index: 0.0284
# bridges ∩ bfs at K=3000: 121 edges, Jaccard Index: 0.0375, Weighted Jaccard Index: 0.0392
# bridges ∩ bfs at K=4000: 219 edges, Jaccard Index: 0.0490, Weighted Jaccard Index: 0.0553
# bridges ∩ bfs at K=5000: 452 edges, Jaccard Index: 0.0788, Weighted Jaccard Index: 0.0877
# bridges ∩ bfs at K=6000: 668 edges, Jaccard Index: 0.0949, Weighted Jaccard Index: 0.0975
# bridges ∩ bfs at K=7000: 865 edges, Jaccard Index: 0.1035, Weighted Jaccard Index: 0.1080
# bridges ∩ bfs at K=8000: 1057 edges, Jaccard Index: 0.1082, Weighted Jaccard Index: 0.1218
# bridges ∩ bfs at K=9000: 1315 edges, Jaccard Index: 0.1183, Weighted Jaccard Index: 0.1363
# bridges ∩ bfs at K=10000: 1585 edges, Jaccard Index: 0.1287, Weighted Jaccard Index: 0.1501
# bridges ∩ dfs at K=1000: 53 edges, Jaccard Index: 0.0463, Weighted Jaccard Index: 0.0568
# bridges ∩ dfs at K=2000: 256 edges, Jaccard Index: 0.0976, Weighted Jaccard Index: 0.1134
# bridges ∩ dfs at K=3000: 518 edges, Jaccard Index: 0.1227, Weighted Jaccard Index: 0.1397
# bridges ∩ dfs at K=4000: 808 edges, Jaccard Index: 0.1394, Weighted Jaccard Index: 0.1576
# bridges ∩ dfs at K=5000: 1150 edges, Jaccard Index: 0.1567, Weighted Jaccard Index: 0.1694
# bridges ∩ dfs at K=6000: 1543 edges, Jaccard Index: 0.1756, Weighted Jaccard Index: 0.1935
# bridges ∩ dfs at K=7000: 2035 edges, Jaccard Index: 0.1972, Weighted Jaccard Index: 0.2187
# bridges ∩ dfs at K=8000: 2592 edges, Jaccard Index: 0.2213, Weighted Jaccard Index: 0.2452
# bridges ∩ dfs at K=9000: 3113 edges, Jaccard Index: 0.2378, Weighted Jaccard Index: 0.2602
# bridges ∩ dfs at K=10000: 3748 edges, Jaccard Index: 0.2580, Weighted Jaccard Index: 0.2752
# bridges ∩ dfs at K=1000: 19 edges, Jaccard Index: 0.0181, Weighted Jaccard Index: 0.0281
# bridges ∩ dfs at K=2000: 74 edges, Jaccard Index: 0.0324, Weighted Jaccard Index: 0.0509
# bridges ∩ dfs at K=3000: 191 edges, Jaccard Index: 0.0554, Weighted Jaccard Index: 0.0769
# bridges ∩ dfs at K=4000: 359 edges, Jaccard Index: 0.0728, Weighted Jaccard Index: 0.0947
# bridges ∩ dfs at K=5000: 590 edges, Jaccard Index: 0.0912, Weighted Jaccard Index: 0.1102
# bridges ∩ dfs at K=6000: 954 edges, Jaccard Index: 0.1237, Weighted Jaccard Index: 0.1482
# bridges ∩ dfs at K=7000: 1309 edges, Jaccard Index: 0.1468, Weighted Jaccard Index: 0.1723
# bridges ∩ dfs at K=8000: 1613 edges, Jaccard Index: 0.1587, Weighted Jaccard Index: 0.1940
# bridges ∩ dfs at K=9000: 1930 edges, Jaccard Index: 0.1675, Weighted Jaccard Index: 0.2032
# bridges ∩ dfs at K=10000: 2303 edges, Jaccard Index: 0.1823, Weighted Jaccard Index: 0.2200
# bridges ∩ dfs at K=1000: 2 edges, Jaccard Index: 0.0028, Weighted Jaccard Index: 0.0043
# bridges ∩ dfs at K=2000: 186 edges, Jaccard Index: 0.0828, Weighted Jaccard Index: 0.1204
# bridges ∩ dfs at K=3000: 350 edges, Jaccard Index: 0.1021, Weighted Jaccard Index: 0.1364
# bridges ∩ dfs at K=4000: 571 edges, Jaccard Index: 0.1236, Weighted Jaccard Index: 0.1631
# bridges ∩ dfs at K=5000: 806 edges, Jaccard Index: 0.1353, Weighted Jaccard Index: 0.1789
# bridges ∩ dfs at K=6000: 1128 edges, Jaccard Index: 0.1561, Weighted Jaccard Index: 0.1938
# bridges ∩ dfs at K=7000: 1418 edges, Jaccard Index: 0.1663, Weighted Jaccard Index: 0.1997
# bridges ∩ dfs at K=8000: 1917 edges, Jaccard Index: 0.1978, Weighted Jaccard Index: 0.2233
# bridges ∩ dfs at K=9000: 2315 edges, Jaccard Index: 0.2107, Weighted Jaccard Index: 0.2361
# bridges ∩ dfs at K=10000: 2703 edges, Jaccard Index: 0.2240, Weighted Jaccard Index: 0.2499
# bridges ∩ dijkstra at K=1000: 24 edges, Jaccard Index: 0.0222, Weighted Jaccard Index: 0.0260
# bridges ∩ dijkstra at K=2000: 143 edges, Jaccard Index: 0.0543, Weighted Jaccard Index: 0.0575
# bridges ∩ dijkstra at K=3000: 328 edges, Jaccard Index: 0.0779, Weighted Jaccard Index: 0.0849
# bridges ∩ dijkstra at K=4000: 497 edges, Jaccard Index: 0.0855, Weighted Jaccard Index: 0.0920
# bridges ∩ dijkstra at K=5000: 788 edges, Jaccard Index: 0.1069, Weighted Jaccard Index: 0.1135
# bridges ∩ dijkstra at K=6000: 1069 edges, Jaccard Index: 0.1189, Weighted Jaccard Index: 0.1305
# bridges ∩ dijkstra at K=7000: 1479 edges, Jaccard Index: 0.1407, Weighted Jaccard Index: 0.1544
# bridges ∩ dijkstra at K=8000: 1943 edges, Jaccard Index: 0.1617, Weighted Jaccard Index: 0.1789
# bridges ∩ dijkstra at K=9000: 2419 edges, Jaccard Index: 0.1784, Weighted Jaccard Index: 0.1961
# bridges ∩ dijkstra at K=10000: 2924 edges, Jaccard Index: 0.1925, Weighted Jaccard Index: 0.2082
# bridges ∩ dijkstra at K=1000: 13 edges, Jaccard Index: 0.0132, Weighted Jaccard Index: 0.0130
# bridges ∩ dijkstra at K=2000: 40 edges, Jaccard Index: 0.0175, Weighted Jaccard Index: 0.0209
# bridges ∩ dijkstra at K=3000: 128 edges, Jaccard Index: 0.0363, Weighted Jaccard Index: 0.0470
# bridges ∩ dijkstra at K=4000: 201 edges, Jaccard Index: 0.0387, Weighted Jaccard Index: 0.0516
# bridges ∩ dijkstra at K=5000: 406 edges, Jaccard Index: 0.0614, Weighted Jaccard Index: 0.0834
# bridges ∩ dijkstra at K=6000: 623 edges, Jaccard Index: 0.0775, Weighted Jaccard Index: 0.0954
# bridges ∩ dijkstra at K=7000: 845 edges, Jaccard Index: 0.0904, Weighted Jaccard Index: 0.1078
# bridges ∩ dijkstra at K=8000: 1072 edges, Jaccard Index: 0.1012, Weighted Jaccard Index: 0.1231
# bridges ∩ dijkstra at K=9000: 1343 edges, Jaccard Index: 0.1110, Weighted Jaccard Index: 0.1360
# bridges ∩ dijkstra at K=10000: 1671 edges, Jaccard Index: 0.1247, Weighted Jaccard Index: 0.1503
# bridges ∩ dijkstra at K=1000: 3 edges, Jaccard Index: 0.0065, Weighted Jaccard Index: 0.0051
# bridges ∩ dijkstra at K=2000: 51 edges, Jaccard Index: 0.0286, Weighted Jaccard Index: 0.0397
# bridges ∩ dijkstra at K=3000: 126 edges, Jaccard Index: 0.0433, Weighted Jaccard Index: 0.0489
# bridges ∩ dijkstra at K=4000: 263 edges, Jaccard Index: 0.0656, Weighted Jaccard Index: 0.0734
# bridges ∩ dijkstra at K=5000: 468 edges, Jaccard Index: 0.0787, Weighted Jaccard Index: 0.0926
# bridges ∩ dijkstra at K=6000: 645 edges, Jaccard Index: 0.0892, Weighted Jaccard Index: 0.1025
# bridges ∩ dijkstra at K=7000: 877 edges, Jaccard Index: 0.1027, Weighted Jaccard Index: 0.1200
# bridges ∩ dijkstra at K=8000: 1127 edges, Jaccard Index: 0.1136, Weighted Jaccard Index: 0.1267
# bridges ∩ dijkstra at K=9000: 1396 edges, Jaccard Index: 0.1230, Weighted Jaccard Index: 0.1361
# bridges ∩ dijkstra at K=10000: 1686 edges, Jaccard Index: 0.1343, Weighted Jaccard Index: 0.1467
# bridges ∩ mst_prim at K=1000: 7 edges, Jaccard Index: 0.0055, Weighted Jaccard Index: 0.0059
# bridges ∩ mst_prim at K=2000: 53 edges, Jaccard Index: 0.0176, Weighted Jaccard Index: 0.0162
# bridges ∩ mst_prim at K=3000: 149 edges, Jaccard Index: 0.0319, Weighted Jaccard Index: 0.0312
# bridges ∩ mst_prim at K=4000: 282 edges, Jaccard Index: 0.0448, Weighted Jaccard Index: 0.0415
# bridges ∩ mst_prim at K=5000: 502 edges, Jaccard Index: 0.0632, Weighted Jaccard Index: 0.0589
# bridges ∩ mst_prim at K=6000: 728 edges, Jaccard Index: 0.0761, Weighted Jaccard Index: 0.0751
# bridges ∩ mst_prim at K=7000: 1102 edges, Jaccard Index: 0.0986, Weighted Jaccard Index: 0.0962
# bridges ∩ mst_prim at K=8000: 1474 edges, Jaccard Index: 0.1156, Weighted Jaccard Index: 0.1135
# bridges ∩ mst_prim at K=9000: 1861 edges, Jaccard Index: 0.1307, Weighted Jaccard Index: 0.1299
# bridges ∩ mst_prim at K=10000: 2274 edges, Jaccard Index: 0.1435, Weighted Jaccard Index: 0.1447
# bridges ∩ mst_prim at K=1000: 23 edges, Jaccard Index: 0.0214, Weighted Jaccard Index: 0.0401
# bridges ∩ mst_prim at K=2000: 97 edges, Jaccard Index: 0.0409, Weighted Jaccard Index: 0.0772
# bridges ∩ mst_prim at K=3000: 212 edges, Jaccard Index: 0.0590, Weighted Jaccard Index: 0.0960
# bridges ∩ mst_prim at K=4000: 340 edges, Jaccard Index: 0.0685, Weighted Jaccard Index: 0.1030
# bridges ∩ mst_prim at K=5000: 584 edges, Jaccard Index: 0.0913, Weighted Jaccard Index: 0.1345
# bridges ∩ mst_prim at K=6000: 808 edges, Jaccard Index: 0.1034, Weighted Jaccard Index: 0.1422
# bridges ∩ mst_prim at K=7000: 1025 edges, Jaccard Index: 0.1129, Weighted Jaccard Index: 0.1516
# bridges ∩ mst_prim at K=8000: 1252 edges, Jaccard Index: 0.1214, Weighted Jaccard Index: 0.1572
# bridges ∩ mst_prim at K=9000: 1600 edges, Jaccard Index: 0.1380, Weighted Jaccard Index: 0.1766
# bridges ∩ mst_prim at K=10000: 1905 edges, Jaccard Index: 0.1497, Weighted Jaccard Index: 0.1883
# bridges ∩ mst_prim at K=1000: 0 edges, Jaccard Index: 0.0000, Weighted Jaccard Index: 0.0000
# bridges ∩ mst_prim at K=2000: 25 edges, Jaccard Index: 0.0124, Weighted Jaccard Index: 0.0128
# bridges ∩ mst_prim at K=3000: 72 edges, Jaccard Index: 0.0226, Weighted Jaccard Index: 0.0222
# bridges ∩ mst_prim at K=4000: 199 edges, Jaccard Index: 0.0454, Weighted Jaccard Index: 0.0503
# bridges ∩ mst_prim at K=5000: 345 edges, Jaccard Index: 0.0599, Weighted Jaccard Index: 0.0744
# bridges ∩ mst_prim at K=6000: 516 edges, Jaccard Index: 0.0710, Weighted Jaccard Index: 0.0890
# bridges ∩ mst_prim at K=7000: 726 edges, Jaccard Index: 0.0853, Weighted Jaccard Index: 0.1080
# bridges ∩ mst_prim at K=8000: 887 edges, Jaccard Index: 0.0883, Weighted Jaccard Index: 0.1147
# bridges ∩ mst_prim at K=9000: 1092 edges, Jaccard Index: 0.0951, Weighted Jaccard Index: 0.1214
# bridges ∩ mst_prim at K=10000: 1333 edges, Jaccard Index: 0.1048, Weighted Jaccard Index: 0.1339
# bridges ∩ bellman_ford at K=1000: 39 edges, Jaccard Index: 0.0338, Weighted Jaccard Index: 0.0407
# bridges ∩ bellman_ford at K=2000: 145 edges, Jaccard Index: 0.0531, Weighted Jaccard Index: 0.0551
# bridges ∩ bellman_ford at K=3000: 313 edges, Jaccard Index: 0.0716, Weighted Jaccard Index: 0.0752
# bridges ∩ bellman_ford at K=4000: 540 edges, Jaccard Index: 0.0908, Weighted Jaccard Index: 0.0956
# bridges ∩ bellman_ford at K=5000: 798 edges, Jaccard Index: 0.1057, Weighted Jaccard Index: 0.1158
# bridges ∩ bellman_ford at K=6000: 1085 edges, Jaccard Index: 0.1184, Weighted Jaccard Index: 0.1293
# bridges ∩ bellman_ford at K=7000: 1521 edges, Jaccard Index: 0.1410, Weighted Jaccard Index: 0.1505
# bridges ∩ bellman_ford at K=8000: 1978 edges, Jaccard Index: 0.1601, Weighted Jaccard Index: 0.1682
# bridges ∩ bellman_ford at K=9000: 2370 edges, Jaccard Index: 0.1707, Weighted Jaccard Index: 0.1766
# bridges ∩ bellman_ford at K=10000: 2851 edges, Jaccard Index: 0.1839, Weighted Jaccard Index: 0.1910
# bridges ∩ bellman_ford at K=1000: 34 edges, Jaccard Index: 0.0384, Weighted Jaccard Index: 0.0414
# bridges ∩ bellman_ford at K=2000: 99 edges, Jaccard Index: 0.0456, Weighted Jaccard Index: 0.0611
# bridges ∩ bellman_ford at K=3000: 167 edges, Jaccard Index: 0.0486, Weighted Jaccard Index: 0.0626
# bridges ∩ bellman_ford at K=4000: 302 edges, Jaccard Index: 0.0604, Weighted Jaccard Index: 0.0701
# bridges ∩ bellman_ford at K=5000: 518 edges, Jaccard Index: 0.0798, Weighted Jaccard Index: 0.1001
# bridges ∩ bellman_ford at K=6000: 688 edges, Jaccard Index: 0.0873, Weighted Jaccard Index: 0.1064
# bridges ∩ bellman_ford at K=7000: 981 edges, Jaccard Index: 0.1053, Weighted Jaccard Index: 0.1224
# bridges ∩ bellman_ford at K=8000: 1216 edges, Jaccard Index: 0.1144, Weighted Jaccard Index: 0.1325
# bridges ∩ bellman_ford at K=9000: 1500 edges, Jaccard Index: 0.1252, Weighted Jaccard Index: 0.1429
# bridges ∩ bellman_ford at K=10000: 1856 edges, Jaccard Index: 0.1401, Weighted Jaccard Index: 0.1610
# bridges ∩ bellman_ford at K=1000: 0 edges, Jaccard Index: 0.0000, Weighted Jaccard Index: 0.0000
# bridges ∩ bellman_ford at K=2000: 16 edges, Jaccard Index: 0.0090, Weighted Jaccard Index: 0.0092
# bridges ∩ bellman_ford at K=3000: 35 edges, Jaccard Index: 0.0113, Weighted Jaccard Index: 0.0121
# bridges ∩ bellman_ford at K=4000: 140 edges, Jaccard Index: 0.0314, Weighted Jaccard Index: 0.0360
# bridges ∩ bellman_ford at K=5000: 327 edges, Jaccard Index: 0.0548, Weighted Jaccard Index: 0.0638
# bridges ∩ bellman_ford at K=6000: 525 edges, Jaccard Index: 0.0713, Weighted Jaccard Index: 0.0767
# bridges ∩ bellman_ford at K=7000: 711 edges, Jaccard Index: 0.0807, Weighted Jaccard Index: 0.0847
# bridges ∩ bellman_ford at K=8000: 946 edges, Jaccard Index: 0.0917, Weighted Jaccard Index: 0.0950
# bridges ∩ bellman_ford at K=9000: 1246 edges, Jaccard Index: 0.1069, Weighted Jaccard Index: 0.1128
# bridges ∩ bellman_ford at K=10000: 1481 edges, Jaccard Index: 0.1149, Weighted Jaccard Index: 0.1193
# bridges ∩ articulation_points at K=1000: 46 edges, Jaccard Index: 0.0345, Weighted Jaccard Index: 0.0305
# bridges ∩ articulation_points at K=2000: 214 edges, Jaccard Index: 0.0752, Weighted Jaccard Index: 0.0750
# bridges ∩ articulation_points at K=3000: 503 edges, Jaccard Index: 0.1152, Weighted Jaccard Index: 0.1263
# bridges ∩ articulation_points at K=4000: 795 edges, Jaccard Index: 0.1342, Weighted Jaccard Index: 0.1467
# bridges ∩ articulation_points at K=5000: 1154 edges, Jaccard Index: 0.1570, Weighted Jaccard Index: 0.1662
# bridges ∩ articulation_points at K=6000: 1606 edges, Jaccard Index: 0.1827, Weighted Jaccard Index: 0.1905
# bridges ∩ articulation_points at K=7000: 2026 edges, Jaccard Index: 0.1960, Weighted Jaccard Index: 0.2012
# bridges ∩ articulation_points at K=8000: 2547 edges, Jaccard Index: 0.2173, Weighted Jaccard Index: 0.2192
# bridges ∩ articulation_points at K=9000: 3073 edges, Jaccard Index: 0.2365, Weighted Jaccard Index: 0.2328
# bridges ∩ articulation_points at K=10000: 3703 edges, Jaccard Index: 0.2575, Weighted Jaccard Index: 0.2515
# bridges ∩ articulation_points at K=1000: 75 edges, Jaccard Index: 0.0597, Weighted Jaccard Index: 0.0883
# bridges ∩ articulation_points at K=2000: 173 edges, Jaccard Index: 0.0647, Weighted Jaccard Index: 0.1033
# bridges ∩ articulation_points at K=3000: 313 edges, Jaccard Index: 0.0785, Weighted Jaccard Index: 0.1135
# bridges ∩ articulation_points at K=4000: 441 edges, Jaccard Index: 0.0814, Weighted Jaccard Index: 0.1226
# bridges ∩ articulation_points at K=5000: 707 edges, Jaccard Index: 0.1027, Weighted Jaccard Index: 0.1480
# bridges ∩ articulation_points at K=6000: 997 edges, Jaccard Index: 0.1215, Weighted Jaccard Index: 0.1680
# bridges ∩ articulation_points at K=7000: 1283 edges, Jaccard Index: 0.1349, Weighted Jaccard Index: 0.1803
# bridges ∩ articulation_points at K=8000: 1574 edges, Jaccard Index: 0.1461, Weighted Jaccard Index: 0.1941
# bridges ∩ articulation_points at K=9000: 1908 edges, Jaccard Index: 0.1580, Weighted Jaccard Index: 0.2064
# bridges ∩ articulation_points at K=10000: 2282 edges, Jaccard Index: 0.1725, Weighted Jaccard Index: 0.2206
# bridges ∩ articulation_points at K=1000: 3 edges, Jaccard Index: 0.0045, Weighted Jaccard Index: 0.0065
# bridges ∩ articulation_points at K=2000: 82 edges, Jaccard Index: 0.0386, Weighted Jaccard Index: 0.0460
# bridges ∩ articulation_points at K=3000: 182 edges, Jaccard Index: 0.0547, Weighted Jaccard Index: 0.0553
# bridges ∩ articulation_points at K=4000: 368 edges, Jaccard Index: 0.0825, Weighted Jaccard Index: 0.0837
# bridges ∩ articulation_points at K=5000: 562 edges, Jaccard Index: 0.0967, Weighted Jaccard Index: 0.1044
# bridges ∩ articulation_points at K=6000: 874 edges, Jaccard Index: 0.1219, Weighted Jaccard Index: 0.1327
# bridges ∩ articulation_points at K=7000: 1150 edges, Jaccard Index: 0.1344, Weighted Jaccard Index: 0.1462
# bridges ∩ articulation_points at K=8000: 1469 edges, Jaccard Index: 0.1484, Weighted Jaccard Index: 0.1647
# bridges ∩ articulation_points at K=9000: 1780 edges, Jaccard Index: 0.1579, Weighted Jaccard Index: 0.1716
# bridges ∩ articulation_points at K=10000: 2177 edges, Jaccard Index: 0.1750, Weighted Jaccard Index: 0.1950

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

K_plot = Ks[-1]
algorithms_plotting = ['BFS', 'DFS', 'Dijkstra', 'Prim', 'B-F', 'Art. Pts.', 'Bridges']
score_methods_plotting = ['Weight', 'Weight Grad', 'EAP', 'EAP-IG']
plt.rcParams.update({'font.size': 15, 'font.family': 'serif'})
plt.set_cmap('plasma')
fig, ax = plt.subplots(1, 3, figsize=(10, 3), sharey=True)
for i, score in enumerate(compute_scores):
    # ax[i].imshow([[jaccard_indices.get((alg1, alg2, K_plot, score)) for alg2 in algorithms] for alg1 in algorithms], vmin=0, vmax=1.0)
    ax[i].imshow([[weighted_jaccard_indices.get((alg1, alg2, K_plot, score)) for alg2 in algorithms] for alg1 in algorithms], vmin=0, vmax=1.0)
    ax[i].set_title(score_methods_plotting[i+1]) # skip weight because they are all the same
    ax[i].set_xticks(range(len(algorithms)))
    ax[i].set_yticks(range(len(algorithms)))
    ax[i].set_xticklabels(algorithms_plotting, rotation=45, ha='right')
    ax[i].set_yticklabels(algorithms_plotting)
# fig.colorbar(plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1.0)), ax=ax, orientation='vertical', fraction=.1, label='Jaccard Index')
fig.colorbar(plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1.0)), ax=ax, orientation='vertical', fraction=.1, label='Weighted Jaccard Index')
# plt.tight_layout()
plt.savefig(f'figures/jaccard_indices_new_K={K_plot}_seed_{seed}.png', dpi=300, bbox_inches='tight')
plt.savefig(f'figures/jaccard_indices_new_K={K_plot}_seed_{seed}.pdf', bbox_inches='tight')
plt.show()

# %%
K_cutoff = len(Ks)
fig, ax = plt.subplots(len(compute_scores), K_cutoff, figsize=(5*K_cutoff, 4*len(compute_scores)), sharey=True, sharex=True)
for i, score_method in enumerate(compute_scores): # skip weight because they are all the same
    for j, K in enumerate(Ks[:K_cutoff]):
        ax[i, j].imshow([[jaccard_indices.get((alg1, alg2, K, score_method)) for alg2 in algorithms] for alg1 in algorithms], vmin=0, vmax=1.0)
        ax[i, j].set_title(f'{score_methods_plotting[i+1]}, K={K}')
        ax[i, j].set_xticks(range(len(algorithms)))
        ax[i, j].set_yticks(range(len(algorithms)))
        ax[i, j].set_xticklabels(algorithms_plotting, rotation=45, ha='right')
        ax[i, j].set_yticklabels(algorithms_plotting)
fig.colorbar(plt.cm.ScalarMappable(cmap='plasma', norm=plt.Normalize(vmin=0, vmax=1.0)), ax=ax, orientation='vertical', fraction=.05, label='Jaccard Index')
# plt.tight_layout()
plt.savefig(f'figures/jaccard_indices_all_scores_new_1_seed_{seed}.png', dpi=300, bbox_inches='tight')
plt.savefig(f'figures/jaccard_indices_all_scores_new_1_seed_{seed}.pdf', bbox_inches='tight')
plt.show()

# %%
def intersection_locations(alg1, alg2, K, score_method):
    circuit1_edges = set(circuits[(alg1, K, score_method)].edges)
    circuit2_edges = set(circuits[(alg2, K, score_method)].edges)
    intersection = circuit1_edges & circuit2_edges
    module_intersection_counts = {}
    for edge in intersection:
        name_components = edge[0].split('.')
        if name_components[-1].isdigit():
            module_name = '.'.join(name_components[:-1])
            if name_components[0] == 'input':
                if int(name_components[-1]) < 128:
                    module_name = 'input_x_in'
                elif int(name_components[-1]) >= 128 and int(name_components[-1]) < 256:
                    module_name = 'input_x_in'
                else:
                    module_name = 'input_x_last'
        else:
            module_name = edge[0]
        if module_name not in module_intersection_counts:
            module_intersection_counts[module_name] = 0
        module_intersection_counts[module_name] += 1
    return module_intersection_counts

intersection_locations('bellman_ford', 'dijkstra', 10000, 'EAP-IG')
# Out:
# {'convs.1.nn.lins.0': 901,
#  'input_x_last': 476,
#  'input_x_in': 847,
#  'convs.0.nn.lins.0': 321,
#  'convs.0.nn.lins.1': 337}

# %%
# Get model baseline performance and embeddings
from salsaclrs.data import SALSACLRSDataLoader
from baselines.core.metrics import calc_metrics

num_samples_evaluation = 128
clean_data_eval = {algorithm : [torch.load(f'{clean_directory}/{algorithm}/data_{i+num_samples}.pt', weights_only=False) for i in range(num_samples_evaluation)] for algorithm in algorithms}

try:
    acc_model = torch.load(f'metrics/val_acc_model_{model_checkpoint}.pt', weights_only=False)
except:
    acc_model = {}
    for task in algorithms:
        loader = SALSACLRSDataLoader(clean_data_eval[task], batch_size=32, shuffle=False)
        avg_model_acc = 0
        for data in loader:
            data.to(model.device)
            if hasattr(data, 'weights'):
                data.edge_attr = data.weights.unsqueeze(1)
            else:
                data.edge_attr = torch.zeros((data.num_edges, 1), device=model.device)
            data.task = task
            out, _, hidden = model(data)
            if task == 'bridges':
                model_accuracy = calc_metrics(data.outputs[0], out, data, output_types[task])['edge_accuracy'].mean().item()
            else:
                model_accuracy = calc_metrics(data.outputs[0], out, data, output_types[task])['node_accuracy'].mean().item()
            avg_model_acc += model_accuracy / len(loader)
        acc_model[task] = avg_model_acc
    torch.save(acc_model, f'metrics/val_acc_model_{model_checkpoint}.pt')

# %%
from salsaclrs.data import SALSACLRSDataLoader
from baselines.core.metrics import calc_metrics

try:
    acc_model = torch.load(f'metrics/val_acc_model_{model_checkpoint}.pt', weights_only=False)
    print(f'Loaded model accuracies')
    acc_circuit = torch.load(f'metrics/val_acc_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt', weights_only=False)
    print(f'Loaded circuit accuracies')
    acc_ablate = torch.load(f'metrics/val_acc_ablate_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt', weights_only=False)
    print(f'Loaded ablate accuracies')
    fid_circuit = torch.load(f'metrics/val_fid_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt', weights_only=False)
    print(f'Loaded circuit FID scores')
    fid_ablate = torch.load(f'metrics/val_fid_ablate_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt', weights_only=False)
    print(f'Loaded ablate FID scores')
except:
    acc_circuit = {}
    acc_ablate = {}
    fid_circuit = {}
    fid_ablate = {}

batch_size = 32
for task in algorithms:
    print(f'Calculating metrics for {task}...')
    loader = SALSACLRSDataLoader(clean_data_eval[task], batch_size=batch_size, shuffle=False)
    for score_method in score_methods:
        for K in Ks:
            if (task, K, score_method) in fid_ablate:
                print(f'Metrics for {task} with K={K} and score method {score_method} already exists. Skipping...')
                continue
            circuit = circuits[(task, K, score_method)]
            avg_acc_circuit = 0
            avg_acc_ablate = 0
            avg_fid_circuit = 0
            avg_fid_ablate = 0
            for data in loader:
                data.to(device)
                if hasattr(data, 'weights'):
                    data.edge_attr = data.weights.unsqueeze(1)
                else:
                    data.edge_attr = torch.zeros((data.num_edges, 1), device=device)
                data.task = task

                # Original model
                out_model, _, _ = model(data)
                data_compare = data.clone()
                for output in data_compare.outputs:
                    if task == 'articulation_points' or task == 'bridges':
                        data_compare[output] = out_model[output].detach() > 0
                    else:
                        data_compare[output] = out_model[output].detach()

                # Circuit model
                out_circuit, _, _ = circuit.forward(data)
                out_ablate, _, _ = circuit.ablate_circuit(data)

                circuit_accuracy = calc_metrics(data.outputs[0], out_circuit, data, output_types[task])[accuracy_types[task]].mean().item()
                ablate_accuracy = calc_metrics(data.outputs[0], out_ablate, data, output_types[task])[accuracy_types[task]].mean().item()
                circuit_fid = calc_metrics(data.outputs[0], out_circuit, data_compare, output_types[task])[accuracy_types[task]].mean().item()
                ablate_fid = calc_metrics(data.outputs[0], out_ablate, data_compare, output_types[task])[accuracy_types[task]].mean().item()

                avg_acc_circuit += circuit_accuracy
                avg_acc_ablate += ablate_accuracy
                avg_fid_circuit += circuit_fid
                avg_fid_ablate += ablate_fid

            circuit_accs = avg_acc_circuit / len(loader)
            ablate_accs = avg_acc_ablate / len(loader)
            circuit_fids = 1 - avg_fid_circuit / len(loader)
            ablate_fids = 1 - avg_fid_ablate / len(loader)

            print(f'Task: {task}, K: {K}, Score: {score_method}, Edges: {circuit.number_of_edges()} | Circuit Acc: {circuit_accs:.4f}, Ablate Acc: {ablate_accs:.4f}, Circuit Fid: {circuit_fids:.6f}, Ablate Fid: {ablate_fids:.6f}')
            acc_circuit[(task, K, score_method)] = circuit_accs
            acc_ablate[(task, K, score_method)] = ablate_accs
            fid_circuit[(task, K, score_method)] = circuit_fids
            fid_ablate[(task, K, score_method)] = ablate_fids

        torch.save(acc_circuit, f'metrics/val_acc_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt')
        torch.save(acc_ablate, f'metrics/val_acc_ablate_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt')
        torch.save(fid_circuit, f'metrics/val_fid_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt')
# Task: mst_prim, K: 6000, Score: weight_grad, Edges: 5333 | Circuit Acc: 0.2554, Ablate Acc: 0.1836, Circuit Fid: 0.751465, Ablate Fid: 0.817383
# Task: mst_prim, K: 7000, Score: weight_grad, Edges: 6285 | Circuit Acc: 0.2710, Ablate Acc: 0.2036, Circuit Fid: 0.749023, Ablate Fid: 0.794434
# Task: mst_prim, K: 8000, Score: weight_grad, Edges: 7238 | Circuit Acc: 0.3315, Ablate Acc: 0.1670, Circuit Fid: 0.661133, Ablate Fid: 0.828125
# Task: mst_prim, K: 9000, Score: weight_grad, Edges: 8200 | Circuit Acc: 0.3682, Ablate Acc: 0.1436, Circuit Fid: 0.612793, Ablate Fid: 0.851562
# Task: mst_prim, K: 10000, Score: weight_grad, Edges: 9157 | Circuit Acc: 0.3755, Ablate Acc: 0.1387, Circuit Fid: 0.594238, Ablate Fid: 0.859375
# Task: mst_prim, K: 1000, Score: EAP, Edges: 485 | Circuit Acc: 0.2158, Ablate Acc: 0.5649, Circuit Fid: 0.759277, Ablate Fid: 0.345703
# Task: mst_prim, K: 2000, Score: EAP, Edges: 1139 | Circuit Acc: 0.2158, Ablate Acc: 0.5122, Circuit Fid: 0.759277, Ablate Fid: 0.429688
# Task: mst_prim, K: 3000, Score: EAP, Edges: 1813 | Circuit Acc: 0.2246, Ablate Acc: 0.4565, Circuit Fid: 0.748535, Ablate Fid: 0.474609
# Task: mst_prim, K: 4000, Score: EAP, Edges: 2497 | Circuit Acc: 0.2026, Ablate Acc: 0.4326, Circuit Fid: 0.783691, Ablate Fid: 0.508789
# Task: mst_prim, K: 5000, Score: EAP, Edges: 3272 | Circuit Acc: 0.1914, Ablate Acc: 0.4414, Circuit Fid: 0.824707, Ablate Fid: 0.505859
# Task: mst_prim, K: 6000, Score: EAP, Edges: 4130 | Circuit Acc: 0.2188, Ablate Acc: 0.2524, Circuit Fid: 0.785645, Ablate Fid: 0.743164
# Task: mst_prim, K: 7000, Score: EAP, Edges: 4843 | Circuit Acc: 0.3003, Ablate Acc: 0.2720, Circuit Fid: 0.705566, Ablate Fid: 0.721680
# Task: mst_prim, K: 8000, Score: EAP, Edges: 5541 | Circuit Acc: 0.2197, Ablate Acc: 0.2710, Circuit Fid: 0.787598, Ablate Fid: 0.721680
# Task: mst_prim, K: 9000, Score: EAP, Edges: 6297 | Circuit Acc: 0.3101, Ablate Acc: 0.2407, Circuit Fid: 0.696289, Ablate Fid: 0.750977
# Task: mst_prim, K: 10000, Score: EAP, Edges: 7013 | Circuit Acc: 0.3159, Ablate Acc: 0.2046, Circuit Fid: 0.692383, Ablate Fid: 0.795898
# Task: mst_prim, K: 1000, Score: EAP-IG, Edges: 411 | Circuit Acc: 0.2393, Ablate Acc: 0.5503, Circuit Fid: 0.732422, Ablate Fid: 0.338379
# Task: mst_prim, K: 2000, Score: EAP-IG, Edges: 1064 | Circuit Acc: 0.2158, Ablate Acc: 0.4971, Circuit Fid: 0.759277, Ablate Fid: 0.417969
# Task: mst_prim, K: 3000, Score: EAP-IG, Edges: 1682 | Circuit Acc: 0.2261, Ablate Acc: 0.4678, Circuit Fid: 0.746582, Ablate Fid: 0.485840
| WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 85 / 1956
# 2026-09-24 20:04:19.807 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 85 / 1956
# 2026-09-24 20:04:23.840 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 94 / 2022
# 2026-09-24 20:04:23.950 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 94 / 2022
# 2026-09-24 20:04:32.860 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 78 / 1986
# 2026-09-24 20:04:32.983 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 78 / 1986
# Task: bridges, K: 9000, Score: EAP-IG, Edges: 6296 | Circuit Acc: 0.7670, Ablate Acc: 0.7324, Circuit Fid: 0.202308, Ablate Fid: 0.255722
# 2026-09-24 20:04:38.019 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 85 / 1956
# 2026-09-24 20:04:38.117 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 85 / 1956
# 2026-09-24 20:04:42.574 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 94 / 2022
# 2026-09-24 20:04:42.671 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 94 / 2022
# 2026-09-24 20:04:51.355 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 78 / 1986
# 2026-09-24 20:04:51.446 | WARNING  | baselines.core.metrics:calc_metrics:77 - MASK METRIC: Truth has less than 5% ones: 78 / 1986
# Task: bridges, K: 10000, Score: EAP-IG, Edges: 7006 | Circuit Acc: 0.7929, Ablate Acc: 0.7318, Circuit Fid: 0.168985, Ablate Fid: 0.257887

# %%
tasks = algorithms
total_number_of_edges = G.number_of_edges()

def edge_count_to_model_sparsity(edge_count):
    return 1 - edge_count / total_number_of_edges

Ks_list = Ks
# ticks = range(0, 500, 100)
# tick_labels = [f'{i}K' for i in range(0, 5)]
cols = len(tasks)
rows = 2
score_markers = ['o', 's', '^', 'd']
fig, axes = plt.subplots(rows, cols, figsize=(2.5 * cols, 4), constrained_layout=True, sharex=True, sharey=True)
for i, task in enumerate(tasks):
    ax_c = axes[0][i]
    ax_a = axes[1][i]
    for score_method, score_plot, marker in zip(score_methods, score_methods_plotting, score_markers):
        x = [edge_count_to_model_sparsity(circuits[(task, K, score_method)].number_of_edges()) for K in Ks_list]

        y_c = [float(acc_circuit.get((task, K, score_method), float('nan'))) for K in Ks_list]
        ax_c.plot(x, y_c, marker=marker, label=score_plot)
        y_a = [float(acc_ablate.get((task, K, score_method), float('nan'))) for K in Ks_list]
        ax_a.plot(x, y_a, marker=marker, label=score_plot)

    ax_c.axhline(y=acc_model[task], color='gray', linestyle='dashed', label='Model Accuracy')
    ax_a.axhline(y=acc_model[task], color='gray', linestyle='dashed', label='Model Accuracy')

    ax_c.set_title(algorithms_plotting[i])
    if i == 0:
        ax_c.set_ylabel('Circuit Acc.')
        ax_a.set_ylabel('Ablated Acc.')
    ax_c.grid(axis='y', alpha=0.3)
    ax_c.set_ylim(0, 1.1)
    ax_a.grid(axis='y', alpha=0.3)
    ax_a.set_ylim(0, 1.1)

fig.text(0.5, -0.05, 'Circuit size (sparsity)', ha='center', va='center')
fig.legend(['Weight', 'Weight Grad', 'EAP', 'EAP-IG', 'Model Accuracy'], loc='lower center', ncol=5, bbox_to_anchor=(0.5, -.2))
plt.savefig(f'figures/accuracy_circuit_ablate_vs_K_new_seed_{seed}.png', dpi=300, bbox_inches='tight')
plt.savefig(f'figures/accuracy_circuit_ablate_vs_K_new_seed_{seed}.pdf', bbox_inches='tight')
plt.show()

# %%
tasks = algorithms
Ks_list = Ks
cols = len(tasks)
rows = 2
score_methods_plotting = ['Weight', 'Weight Grad', 'EAP', 'EAP-IG']
score_markers = ['o', 's', '^', 'd']
fig, axes = plt.subplots(rows, cols, figsize=(2.5 * cols, 4), constrained_layout=True, sharex=True, sharey=True)
for i, task in enumerate(tasks):
    ax_c = axes[0][i]
    ax_a = axes[1][i]
    for score_method, score_plot, marker in zip(score_methods, score_methods_plotting, score_markers):
        x = [edge_count_to_model_sparsity(circuits[(task, K, score_method)].number_of_edges()) for K in Ks_list]

        y_c = [1 - float(fid_circuit.get((task, K, score_method), float('nan'))) for K in Ks_list]
        ax_c.plot(x, y_c, marker=marker, label=score_plot)
        y_a = [float(fid_ablate.get((task, K, score_method), float('nan'))) for K in Ks_list]
        ax_a.plot(x, y_a, marker=marker, label=score_plot)

    ax_c.set_title(algorithms_plotting[i])
    if i == 0:
        ax_c.set_ylabel(r'1 - Fid$^-$')
        ax_a.set_ylabel(r'Fid$^+$')
    ax_c.grid(axis='y', alpha=0.3)
    ax_c.set_ylim(0, 1.1)
    ax_a.grid(axis='y', alpha=0.3)
    ax_a.set_ylim(0, 1.1)

fig.text(0.5, -0.05, 'Circuit size (sparsity)', ha='center', va='center')
fig.legend(score_methods_plotting, loc='lower center', ncol=5, bbox_to_anchor=(0.5, -.2))
plt.savefig(f'figures/fidelity_circuit_ablate_vs_K_new_seed_{seed}.png', dpi=300, bbox_inches='tight')
plt.savefig(f'figures/fidelity_circuit_ablate_vs_K_new_seed_{seed}.pdf', bbox_inches='tight')

# %%
def characterization_score(circuit_fid, ablate_fid, w_circuit=0.5, w_ablate=0.5):
    assert w_circuit + w_ablate == 1.0, "Weights must sum to 1."
    if circuit_fid == 0 or ablate_fid == 0:
        return 0.0
    return 1 / (w_circuit / (1-circuit_fid) + w_ablate / ablate_fid)

try:
    circuit_char_scores = torch.load(f'metrics/val_char_scores_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt', weights_only=False)
except:
    circuit_char_scores = {}

for task in algorithms:
    for K in Ks:
        for score_method in score_methods:
            circuit_fid = fid_circuit.get((task, K, score_method))
            ablate_fid = fid_ablate.get((task, K, score_method))
            char_score = characterization_score(circuit_fid, ablate_fid)
            circuit_char_scores[(task, K, score_method)] = char_score
torch.save(circuit_char_scores, f'metrics/val_char_scores_circuit_{circuit_algorithm}_new_prune={prune}_{model_checkpoint}.pt')

# %%
# Plot characterization scores vs circuit size for each task
tasks = algorithms
Ks_list = Ks
methods = score_methods
markers = score_markers[:len(methods)]
fig, axes = plt.subplots(1, len(tasks), figsize=(2.5 * len(tasks), 2.5), sharey=True, constrained_layout=True)

for i, task in enumerate(tasks):
    ax = axes[i] if len(tasks) > 1 else axes
    for method, method_plot, marker in zip(methods, score_methods_plotting, markers):
        xs = []
        ys = []
        for K in Ks_list:
            key = (task, K, method)
            if key in circuit_char_scores and (task, K, method) in circuits:
                try:
                    xs.append(edge_count_to_model_sparsity(circuits[(task, K, method)].number_of_edges()))
                    ys.append(float(circuit_char_scores[key]))
                except Exception:
                    continue
        if xs:
            ax.plot(xs, ys, marker=marker, label=method_plot)
    ax.set_title(algorithms_plotting[i])
    if i == 0:
        ax.set_ylabel('Characterization\nScore')
    ax.grid(alpha=0.3)
    ax.set_ylim(0, 1)
    
fig.text(0.5, -0.05, 'Circuit size (sparsity)', ha='center', va='center')
fig.legend(score_methods_plotting, loc='lower center', ncol=len(methods), bbox_to_anchor=(0.5, -0.3))
plt.savefig(f'figures/characterization_scores_new_seed_{seed}.png', dpi=300, bbox_inches='tight')
plt.savefig(f'figures/characterization_scores_new_seed_{seed}.pdf', bbox_inches='tight')
plt.show()
